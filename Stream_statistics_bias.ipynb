# %% [markdown]
# <a href="https://colab.research.google.com/github/bjornemonts/stream-statistics/blob/main/Stream_statistics_bias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

print("Installing necessary packages")
os.system("pip install astropy")
os.system("pip install astropy-helpers")
os.system("pip install matplotlib")
os.system("pip install spectral-cube")
os.system("pip install specutils")

print("Complete")
# Out:
# Installing necessary packages
# Complete

# %%
print("Obtaining the fits cube")
os.system("wget https://www.cv.nrao.edu/~bemonts/data_bias_py.fits")
print("Complete")
# Out:
# Obtaining the fits cube
# Complete

# %%
print("Import necessary packages") 

from astropy.io import fits
import astropy.units as u
from astropy.utils import data
from spectral_cube import SpectralCube

print("Complete")
# Out:
# Import necessary packages
# Complete

# %%
bias_data = fits.open("data_bias_py.fits")
cube = SpectralCube.read(bias_data)
print(cube)
# Out:
# WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU. [astropy.io.fits.hdu.image]
# WARNING:astropy:VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU.
# WARNING: StokesWarning: Cube is a Stokes cube, returning spectral cube for I component [spectral_cube.io.core]
# WARNING:astropy:StokesWarning: Cube is a Stokes cube, returning spectral cube for I component
# SpectralCube with shape=(31, 212, 108) and unit=Jy / beam:
#  n_x:    108  type_x: RA---SIN  unit_x: deg    range:   102.713069 deg:  102.719023 deg
#  n_y:    212  type_y: DEC--SIN  unit_y: deg    range:    41.507022 deg:   41.515814 deg
#  n_s:     31  type_s: VOPT      unit_s: m / s  range: -2620532.353 m / s:  418448.597 m / s

# %%
import numpy as np
import matplotlib.pyplot as plt

for i in range(50, 65):
  for j in range(50, 80):
    for r in range (12, 14):
      x = i
      y = j
      z = r
      print(x, y, z)
# Out:
# 50 50 12
# 50 50 13
# 50 51 12
# 50 51 13
# 50 52 12
# 50 52 13
# 50 53 12
# 50 53 13
# 50 54 12
# 50 54 13
# 50 55 12
# 50 55 13
# 50 56 12
# 50 56 13
# 50 57 12
# 50 57 13
# 50 58 12
# 50 58 13
# 50 59 12
# 50 59 13
# 50 60 12
# 50 60 13
# 50 61 12
# 50 61 13
# 50 62 12
# 50 62 13
# 50 63 12
# 50 63 13
# 50 64 12
# 50 64 13
# 50 65 12
# 50 65 13
# 50 66 12
# 50 66 13
# 50 67 12
# 50 67 13
# 50 68 12
# 50 68 13
# 50 69 12
# 50 69 13
# 50 70 12
# 50 70 13
# 50 71 12
# 50 71 13
# 50 72 12
# 50 72 13
# 50 73 12
# 50 73 13
# 50 74 12
# 50 74 13
# 50 75 12
# 50 75 13
# 50 76 12
# 50 76 13
# 50 77 12
# 50 77 13
# 50 78 12
# 50 78 13
# 50 79 12
# 50 79 13
# 51 50 12
# 51 50 13
# 51 51 12
# 51 51 13
# 51 52 12
# 51 52 13
# 51 53 12
# 51 53 13
# 51 54 12
# 51 54 13
# 51 55 12
# 51 55 13
# 51 56 12
# 51 56 13
# 51 57 12
# 51 57 13
# 51 58 12
# 51 58 13
# 51 59 12
# 51 59 13
# 51 60 12
# 51 60 13
# 51 61 12
# 51 61 13
# 51 62 12
# 51 62 13
# 51 63 12
# 51 63 13
# 51 64 12
# 51 64 13
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

for i in range(50, 51):
  for j in range(50, 51):
    for r in range (12, 13):
      x = i
      y = j
      z = r
      np.sum(cube[:,y,x])

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1 = cube[12:14, 50:80, 50:65]

print(sub_cube1)

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1 = np.average(sub_cube1)
print(a1)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# SpectralCube with shape=(2, 30, 15) and unit=Jy / beam:
#  n_x:     15  type_x: RA---SIN  unit_x: deg    range:   102.715462 deg:  102.716241 deg
#  n_y:     30  type_y: DEC--SIN  unit_y: deg    range:    41.509105 deg:   41.510314 deg
#  n_s:      2  type_s: VOPT      unit_s: m / s  range:  -898443.148 m / s: -797143.783 m / s
# 0.00016747422

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube2 = cube[14:16, 80:110, 50:65]

print(sub_cube2)

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a2 = np.average(sub_cube2)
print(a2)
# Out:
# SpectralCube with shape=(2, 30, 15) and unit=Jy / beam:
#  n_x:     15  type_x: RA---SIN  unit_x: deg    range:   102.715462 deg:  102.716241 deg
#  n_y:     30  type_y: DEC--SIN  unit_y: deg    range:    41.510355 deg:   41.511564 deg
#  n_s:      2  type_s: VOPT      unit_s: m / s  range: -1101041.878 m / s: -999742.513 m / s
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# 9.300147e-05

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube3 = cube[16:18, 110:140, 50:65]

print(sub_cube3)

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a3 = np.average(sub_cube3)
print(a3)
# Out:
# SpectralCube with shape=(2, 30, 15) and unit=Jy / beam:
#  n_x:     15  type_x: RA---SIN  unit_x: deg    range:   102.715462 deg:  102.716241 deg
#  n_y:     30  type_y: DEC--SIN  unit_y: deg    range:    41.511605 deg:   41.512814 deg
#  n_s:      2  type_s: VOPT      unit_s: m / s  range: -1303640.608 m / s:-1202341.243 m / s
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# 0.00012055356

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube4 = cube[18:20, 140:170, 50:65]

print(sub_cube4)

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a4 = np.average(sub_cube4)
print(a4)
# Out:
# SpectralCube with shape=(2, 30, 15) and unit=Jy / beam:
#  n_x:     15  type_x: RA---SIN  unit_x: deg    range:   102.715461 deg:  102.716241 deg
#  n_y:     30  type_y: DEC--SIN  unit_y: deg    range:    41.512855 deg:   41.514064 deg
#  n_s:      2  type_s: VOPT      unit_s: m / s  range: -1506239.338 m / s:-1404939.973 m / s
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# 8.5050844e-05

# %%
import numpy as np

print(a1)
print(a2)
print(a3)
print(a4)

sum = a1 + a2 + a3 + a4
print("Sum = ", sum)
# Out:
# 0.00016747422
# 9.300147e-05
# 0.00012055356
# 8.5050844e-05
# Sum =  0.00046608012

# %%
 import scipy.stats

 scipy.stats.norm.sf(abs(5.7))
# Out:
# 5.99037140106353e-09

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1p2 = cube[12:14, 50:80, 50:65]
sub_cube2p2 = cube[14:16, 80:110, 50:65]
sub_cube3p2 = cube[16:18, 110:140, 50:65]
sub_cube4p2 = cube[18:20, 140:170, 50:65]

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1p2 = np.average(sub_cube1p2)
print(a1p2)

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a2p2 = np.average(sub_cube2p2)
print(a2p2)

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a3p2 = np.average(sub_cube3p2)
print(a3p2)

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a4p2 = np.average(sub_cube4p2)
print(a4p2)

sum_p2 = a1p2 + a2p2 + a3p2 + a4p2
print("Sum = ", sum_p2)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1p2 = cube[12:14, 50:80, 50:65]
sub_cube2p2 = cube[14:16, 80:110, 50:65]
sub_cube3p2 = cube[16:18, 110:140, 50:65]
sub_cube4p2 = cube[18:20, 140:170, 50:65]

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1p2 = np.average(sub_cube1p2)
print(a1p2)

a3p2 = np.average(sub_cube3p2)
print(a3p2)

a4p2 = np.average(sub_cube4p2)
print(a4p2)

sum_p2 = a1p2 + a2p2 + a3p2 + a4p2
print("Sum = ", sum_p2)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1p2 = cube[12:14, 52:82, 50:65]
sub_cube2p2 = cube[14:16, 82:112, 50:65]
sub_cube3p2 = cube[16:18, 112:142, 50:65]
sub_cube4p2 = cube[18:20, 142:172, 50:65]

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1p2 = np.average(sub_cube1p2)
print(a1p2)

a2p2 = np.average(sub_cube2p2)
print(a1p2)

a3p2 = np.average(sub_cube3p2)
print(a3p2)

a4p2 = np.average(sub_cube4p2)
print(a4p2)

sum_p2 = a1p2 + a2p2 + a3p2 + a4p2
print("Sum = ", sum_p2)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...

# %%
difference = sum - sum_p2
print(difference)

diff_sigma = 5.7 - difference * 5.7
print(diff_sigma)
# Out:
# 1.0754738e-06
# 5.699993869799073

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1p5 = cube[12:14, 45:85, 50:65]
sub_cube2p5 = cube[14:16, 85:115, 50:65]
sub_cube3p5 = cube[16:18, 115:145, 50:65]
sub_cube4p5 = cube[18:20, 145:175, 50:65]

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1p5 = np.average(sub_cube1p5)
print(a1p5)

a2p5 = np.average(sub_cube2p5)
print(a2p5)

a3p5 = np.average(sub_cube3p5)
print(a3p5)

a4p5 = np.average(sub_cube4p5)
print(a4p5)

sum_p5 = a1p5 + a2p5 + a3p5 + a4p5
print("Sum = ", sum_p2)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1xp2 = cube[12:14, 50:80, 52:67]
sub_cube2xp2 = cube[14:16, 80:110, 52:67]
sub_cube3xp2 = cube[16:18, 110:140, 52:67]
sub_cube4xp2 = cube[18:20, 140:170, 52:67]

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1xp2 = np.average(sub_cube1xp2)
print(a1xp2)

a2xp2 = np.average(sub_cube2xp2)
print(a2xp2)

a3xp2 = np.average(sub_cube3xp2)
print(a3xp2)

a4xp2 = np.average(sub_cube4xp2)
print(a4xp2)

sum_xp2 = a1xp2 + a2xp2 + a3xp2 + a4xp2
print("Sum_xp2 = ", sum_xp2)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...

# %%
print(sum_xp2)

diff_sigma_xp2 = (sum_xp2 * 5.7) / 0.00046608012
print(diff_sigma_xp2)
# Out:
# 0.00044085528
# 5.391508830933639

# %%
 import scipy.stats

P_norm = scipy.stats.norm.sf(abs(5.7))
print(P_norm)

P_stat = scipy.stats.norm.sf(abs(diff_sigma_xp2))
print(P_stat)

P_correction = P_stat / 5
print(P_correction)
# Out:
# 5.99037140106353e-09
# 3.4934262477491787e-08
# 6.9868524954983575e-09

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1 = cube[12:14, 50:80, 50:65]
sub_cube1_xp1 = cube[12:14, 50:80, 51:66]
sub_cube1_xp2 = cube[12:14, 50:80, 52:67]
sub_cube1_xp3 = cube[12:14, 50:80, 53:68]
sub_cube1_xp4 = cube[12:14, 50:80, 54:69]
sub_cube1_xp5 = cube[12:14, 50:80, 55:70]
sub_cube1_xp6 = cube[12:14, 50:80, 56:71]
sub_cube1_xp7 = cube[12:14, 50:80, 57:72]
sub_cube1_xn1 = cube[12:14, 50:80, 49:64]
sub_cube1_xn2 = cube[12:14, 50:80, 48:63]
sub_cube1_xn3 = cube[12:14, 50:80, 47:62]
sub_cube1_xn4 = cube[12:14, 50:80, 46:61]
sub_cube1_xn5 = cube[12:14, 50:80, 45:60]
sub_cube1_xn6 = cube[12:14, 50:80, 44:59]
sub_cube1_xn7 = cube[12:14, 50:80, 43:58]

sub_cube2 = cube[14:16, 80:110, 50:65]
sub_cube2_xp1 = cube[14:16, 80:110, 51:66]
sub_cube2_xp2 = cube[14:16, 80:110, 52:67]
sub_cube2_xp3 = cube[14:16, 80:110, 53:68]
sub_cube2_xp4 = cube[14:16, 80:110, 54:69]
sub_cube2_xp5 = cube[14:16, 80:110, 55:70]
sub_cube2_xp6 = cube[14:16, 80:110, 56:71]
sub_cube2_xp7 = cube[14:16, 80:110, 57:72]
sub_cube2_xn1 = cube[14:16, 80:110, 49:64]
sub_cube2_xn2 = cube[14:16, 80:110, 48:63]
sub_cube2_xn3 = cube[14:16, 80:110, 47:62]
sub_cube2_xn4 = cube[14:16, 80:110, 46:61]
sub_cube2_xn5 = cube[14:16, 80:110, 45:60]
sub_cube2_xn6 = cube[14:16, 80:110, 44:59]
sub_cube2_xn7 = cube[14:16, 80:110, 43:58]

sub_cube3 = cube[16:18, 110:140, 50:65]
sub_cube3_xp1 = cube[16:18, 110:140, 51:66]
sub_cube3_xp2 = cube[16:18, 110:140, 52:67]
sub_cube3_xp3 = cube[16:18, 110:140, 53:68]
sub_cube3_xp4 = cube[16:18, 110:140, 54:69]
sub_cube3_xp5 = cube[16:18, 110:140, 55:70]
sub_cube3_xp6 = cube[16:18, 110:140, 56:71]
sub_cube3_xp7 = cube[16:18, 110:140, 57:72]
sub_cube3_xn1 = cube[16:18, 110:140, 49:64]
sub_cube3_xn2 = cube[16:18, 110:140, 48:63]
sub_cube3_xn3 = cube[16:18, 110:140, 47:62]
sub_cube3_xn4 = cube[16:18, 110:140, 46:61]
sub_cube3_xn5 = cube[16:18, 110:140, 45:60]
sub_cube3_xn6 = cube[16:18, 110:140, 44:59]
sub_cube3_xn7 = cube[16:18, 110:140, 43:58]

sub_cube4 = cube[18:20, 140:170, 50:65]
sub_cube4_xp1 = cube[18:20, 140:170, 51:66]
sub_cube4_xp2 = cube[18:20, 140:170, 52:67]
sub_cube4_xp3 = cube[18:20, 140:170, 53:68]
sub_cube4_xp4 = cube[18:20, 140:170, 54:69]
sub_cube4_xp5 = cube[18:20, 140:170, 55:70]
sub_cube4_xp6 = cube[18:20, 140:170, 56:71]
sub_cube4_xp7 = cube[18:20, 140:170, 57:72]
sub_cube4_xn1 = cube[18:20, 140:170, 49:64]
sub_cube4_xn2 = cube[18:20, 140:170, 48:63]
sub_cube4_xn3 = cube[18:20, 140:170, 47:62]
sub_cube4_xn4 = cube[18:20, 140:170, 46:61]
sub_cube4_xn5 = cube[18:20, 140:170, 45:60]
sub_cube4_xn6 = cube[18:20, 140:170, 44:59]
sub_cube4_xn7 = cube[18:20, 140:170, 43:58]

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1 = np.average(sub_cube1)
a1_xp1 = np.average(sub_cube1_xp1)
a1_xp2 = np.average(sub_cube1_xp2)
a1_xp3 = np.average(sub_cube1_xp3)
a1_xp4 = np.average(sub_cube1_xp4)
a1_xp5 = np.average(sub_cube1_xp5)
a1_xp6 = np.average(sub_cube1_xp6)
a1_xp7 = np.average(sub_cube1_xp7)
a1_xn1 = np.average(sub_cube1_xn1)
a1_xn2 = np.average(sub_cube1_xn2)
a1_xn3 = np.average(sub_cube1_xn3)
a1_xn4 = np.average(sub_cube1_xn4)
a1_xn5 = np.average(sub_cube1_xn5)
a1_xn6 = np.average(sub_cube1_xn6)
a1_xn7 = np.average(sub_cube1_xn7)

a2 = np.average(sub_cube2)
a2_xp1 = np.average(sub_cube2_xp1)
a2_xp2 = np.average(sub_cube2_xp2)
a2_xp3 = np.average(sub_cube2_xp3)
a2_xp4 = np.average(sub_cube2_xp4)
a2_xp5 = np.average(sub_cube2_xp5)
a2_xp6 = np.average(sub_cube2_xp6)
a2_xp7 = np.average(sub_cube2_xp7)
a2_xn1 = np.average(sub_cube2_xn1)
a2_xn2 = np.average(sub_cube2_xn2)
a2_xn3 = np.average(sub_cube2_xn3)
a2_xn4 = np.average(sub_cube2_xn4)
a2_xn5 = np.average(sub_cube2_xn5)
a2_xn6 = np.average(sub_cube2_xn6)
a2_xn7 = np.average(sub_cube2_xn7)

a3 = np.average(sub_cube3)
a3_xp1 = np.average(sub_cube3_xp1)
a3_xp2 = np.average(sub_cube3_xp2)
a3_xp3 = np.average(sub_cube3_xp3)
a3_xp4 = np.average(sub_cube3_xp4)
a3_xp5 = np.average(sub_cube3_xp5)
a3_xp6 = np.average(sub_cube3_xp6)
a3_xp7 = np.average(sub_cube3_xp7)
a3_xn1 = np.average(sub_cube3_xn1)
a3_xn2 = np.average(sub_cube3_xn2)
a3_xn3 = np.average(sub_cube3_xn3)
a3_xn4 = np.average(sub_cube3_xn4)
a3_xn5 = np.average(sub_cube3_xn5)
a3_xn6 = np.average(sub_cube3_xn6)
a3_xn7 = np.average(sub_cube3_xn7)

a4 = np.average(sub_cube4)
a4_xp1 = np.average(sub_cube4_xp1)
a4_xp2 = np.average(sub_cube4_xp2)
a4_xp3 = np.average(sub_cube4_xp3)
a4_xp4 = np.average(sub_cube4_xp4)
a4_xp5 = np.average(sub_cube4_xp5)
a4_xp6 = np.average(sub_cube4_xp6)
a4_xp7 = np.average(sub_cube4_xp7)
a4_xn1 = np.average(sub_cube4_xn1)
a4_xn2 = np.average(sub_cube4_xn2)
a4_xn3 = np.average(sub_cube4_xn3)
a4_xn4 = np.average(sub_cube4_xn4)
a4_xn5 = np.average(sub_cube4_xn5)
a4_xn6 = np.average(sub_cube4_xn6)
a4_xn7 = np.average(sub_cube4_xn7)

sum = a1 + a2 + a3 + a4
sum_xp1 = a1_xp1 + a2_xp1 + a3_xp1 + a4_xp1
sum_xp2 = a1_xp2 + a2_xp2 + a3_xp2 + a4_xp2
sum_xp3 = a1_xp3 + a2_xp3 + a3_xp3 + a4_xp3
sum_xp4 = a1_xp4 + a2_xp4 + a3_xp4 + a4_xp4
sum_xp5 = a1_xp5 + a2_xp5 + a3_xp5 + a4_xp5
sum_xp6 = a1_xp6 + a2_xp6 + a3_xp6 + a4_xp6
sum_xp7 = a1_xp7 + a2_xp7 + a3_xp7 + a4_xp7
sum_xn1 = a1_xn1 + a2_xn1 + a3_xn1 + a4_xn1
sum_xn2 = a1_xn2 + a2_xn2 + a3_xn2 + a4_xn2
sum_xn3 = a1_xn3 + a2_xn3 + a3_xn3 + a4_xn3
sum_xn4 = a1_xn4 + a2_xn4 + a3_xn4 + a4_xn4
sum_xn5 = a1_xn5 + a2_xn5 + a3_xn5 + a4_xn5
sum_xn6 = a1_xn6 + a2_xn6 + a3_xn6 + a4_xn6
sum_xn7 = a1_xn7 + a2_xn7 + a3_xn7 + a4_xn7

print("Sum = ", sum)
print("Sum_xp1 = ", sum_xp1)
print("Sum_xn1 = ", sum_xn1)
print("Sum_xp2 = ", sum_xp2)
print("Sum_xn2 = ", sum_xn2)
print("Sum_xp3 = ", sum_xp3)
print("Sum_xn3 = ", sum_xn3)
print("Sum_xp4 = ", sum_xp4)
print("Sum_xn4 = ", sum_xn4)
print("Sum_xp5 = ", sum_xp5)
print("Sum_xn5 = ", sum_xn5)
print("Sum_xp6 = ", sum_xp6)
print("Sum_xn6 = ", sum_xn6)
print("Sum_xp7 = ", sum_xp7)
print("Sum_xn7 = ", sum_xn7)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...

# %%
diff_sigma = (sum * 5.7) / 0.00046608012
diff_sigma_xp1 = (sum_xp1 * 5.7) / 0.00046608012
diff_sigma_xn1 = (sum_xn1 * 5.7) / 0.00046608012
diff_sigma_xp2 = (sum_xp2 * 5.7) / 0.00046608012
diff_sigma_xn2 = (sum_xn2 * 5.7) / 0.00046608012
diff_sigma_xp3 = (sum_xp3 * 5.7) / 0.00046608012
diff_sigma_xn3 = (sum_xn3 * 5.7) / 0.00046608012
diff_sigma_xp4 = (sum_xp4 * 5.7) / 0.00046608012
diff_sigma_xn4 = (sum_xn4 * 5.7) / 0.00046608012
diff_sigma_xp5 = (sum_xp5 * 5.7) / 0.00046608012
diff_sigma_xn5 = (sum_xn5 * 5.7) / 0.00046608012
diff_sigma_xp6 = (sum_xp6 * 5.7) / 0.00046608012
diff_sigma_xn6 = (sum_xn6 * 5.7) / 0.00046608012
diff_sigma_xp7 = (sum_xp7 * 5.7) / 0.00046608012
diff_sigma_xn7 = (sum_xn7 * 5.7) / 0.00046608012


print("Sigma p0 = ", diff_sigma)
print("Sigma xp1 = ", diff_sigma_xp1)
print("Sigma xn1 = ", diff_sigma_xn1)
print("Sigma xp2 = ", diff_sigma_xp2)
print("Sigma xn2 = ", diff_sigma_xn2)
print("Sigma xp3 = ", diff_sigma_xp3)
print("Sigma xn3 = ", diff_sigma_xn3)
print("Sigma xp4 = ", diff_sigma_xp4)
print("Sigma xn4 = ", diff_sigma_xn4)
print("Sigma xp5 = ", diff_sigma_xp5)
print("Sigma xn5 = ", diff_sigma_xn5)
print("Sigma xp6 = ", diff_sigma_xp6)
print("Sigma xn6 = ", diff_sigma_xn6)
print("Sigma xp7 = ", diff_sigma_xp7)
print("Sigma xn7 = ", diff_sigma_xn7)
# Out:
# Sigma p0 =  5.700000006504246
# Sigma xp1 =  5.576200837228169
# Sigma xn1 =  5.757903744527011
# Sigma xp2 =  5.391508830933639
# Sigma xn2 =  5.747009087327803
# Sigma xp3 =  5.152778129006695
# Sigma xn3 =  5.666618412373691
# Sigma xp4 =  4.868351371523527
# Sigma xn4 =  5.5182390826376135
# Sigma xp5 =  4.547608378183273
# Sigma xn5 =  5.30543929500356
# Sigma xp6 =  4.200455033023668
# Sigma xn6 =  5.03362775968092
# Sigma xp7 =  3.836797931942181
# Sigma xn7 =  4.709761481786349

# %%
import scipy.stats

P_norm = scipy.stats.norm.sf(abs(5.7))

P_stat = scipy.stats.norm.sf(abs(diff_sigma))
P_stat_xp1 = scipy.stats.norm.sf(abs(diff_sigma_xp1))
P_stat_xn1 = scipy.stats.norm.sf(abs(diff_sigma_xn1))
P_stat_xp2 = scipy.stats.norm.sf(abs(diff_sigma_xp2))
P_stat_xn2 = scipy.stats.norm.sf(abs(diff_sigma_xn2))
P_stat_xp3 = scipy.stats.norm.sf(abs(diff_sigma_xp3))
P_stat_xn3 = scipy.stats.norm.sf(abs(diff_sigma_xn3))
P_stat_xp4 = scipy.stats.norm.sf(abs(diff_sigma_xp4))
P_stat_xn4 = scipy.stats.norm.sf(abs(diff_sigma_xn4))
P_stat_xp5 = scipy.stats.norm.sf(abs(diff_sigma_xp5))
P_stat_xn5 = scipy.stats.norm.sf(abs(diff_sigma_xn5))
P_stat_xp6 = scipy.stats.norm.sf(abs(diff_sigma_xp6))
P_stat_xn6 = scipy.stats.norm.sf(abs(diff_sigma_xn6))
P_stat_xp7 = scipy.stats.norm.sf(abs(diff_sigma_xp7))
P_stat_xn7 = scipy.stats.norm.sf(abs(diff_sigma_xn7))

P_corr = P_stat / P_norm
P_corr_xp1 = P_stat_xp1 / (3 * P_norm)
P_corr_xn1 = P_stat_xn1 / (3 * P_norm)
P_corr_xp2 = P_stat_xp2 / (5 * P_norm)
P_corr_xn2 = P_stat_xn2 / (5 * P_norm)
P_corr_xp3 = P_stat_xp3 / (7 * P_norm)
P_corr_xn3 = P_stat_xn3 / (7 * P_norm)
P_corr_xp4 = P_stat_xp4 / (9 * P_norm)
P_corr_xn4 = P_stat_xn4 / (9 * P_norm)
P_corr_xp5 = P_stat_xp5 / (11 * P_norm)
P_corr_xn5 = P_stat_xn5 / (11 * P_norm)
P_corr_xp6 = P_stat_xp6 / (13 * P_norm)
P_corr_xn6 = P_stat_xn6 / (13 * P_norm)
P_corr_xp7 = P_stat_xp7 / (15 * P_norm)
P_corr_xn7 = P_stat_xn7 / (15 * P_norm)

print(P_corr)
print("Pos1 =",P_corr_xp1)
print("Neg1 =",P_corr_xn1)
print("Pos2 =",P_corr_xp2)
print("Neg2 =",P_corr_xn2)
print("Pos3 =",P_corr_xp3)
print("Neg3 =",P_corr_xn3)
print("Pos4 =",P_corr_xp4)
print("Neg4 =",P_corr_xn4)
print("Pos5 =",P_corr_xp5)
print("Neg5 =",P_corr_xn5)
print("Pos6 =",P_corr_xp6)
print("Neg6 =",P_corr_xn6)
print("Pos7 =",P_corr_xp7)
print("Neg7 =",P_corr_xn7)
# Out:
# 0.9999999618460587
# Pos1 = 0.6839534250648434
# Neg1 = 0.23694939101573653
# Pos2 = 1.1663471307067725
# Neg2 = 0.15163642356051488
# Pos3 = 3.0603344128635825
# Neg3 = 0.17366344308959683
# Pos4 = 10.436480652655053
# Neg4 = 0.3175590370142689
# Pos5 = 41.17135873075165
# Neg5 = 0.8528987844307279
# Pos6 = 171.03027888499483
# Neg6 = 3.090111481220992
# Pos7 = 693.6072583180819
# Neg7 = 13.800304741931154

# %%
P_corr = P_stat / (3 * P_norm)
P_corr_xp1 = P_stat_xp1 / (5 * P_norm)
P_corr_xn1 = P_stat_xn1 / (1 * P_norm)
P_corr_xp2 = P_stat_xp2 / (7 * P_norm)
P_corr_xn2 = P_stat_xn2 / (3 * P_norm)
P_corr_xp3 = P_stat_xp3 / (9 * P_norm)
P_corr_xn3 = P_stat_xn3 / (5 * P_norm)
P_corr_xp4 = P_stat_xp4 / (11 * P_norm)
P_corr_xn4 = P_stat_xn4 / (7 * P_norm)
P_corr_xp5 = P_stat_xp5 / (13 * P_norm)
P_corr_xn5 = P_stat_xn5 / (9 * P_norm)
P_corr_xp6 = P_stat_xp6 / (15 * P_norm)
P_corr_xn6 = P_stat_xn6 / (11 * P_norm)
P_corr_xp7 = P_stat_xp7 / (17 * P_norm)
P_corr_xn7 = P_stat_xn7 / (13 * P_norm)

print(P_corr)
print("Pos1 =",P_corr_xp1)
print("Neg1 =",P_corr_xn1)
print("Pos2 =",P_corr_xp2)
print("Neg2 =",P_corr_xn2)
print("Pos3 =",P_corr_xp3)
print("Neg3 =",P_corr_xn3)
print("Pos4 =",P_corr_xp4)
print("Neg4 =",P_corr_xn4)
print("Pos5 =",P_corr_xp5)
print("Neg5 =",P_corr_xn5)
print("Pos6 =",P_corr_xp6)
print("Neg6 =",P_corr_xn6)
print("Pos7 =",P_corr_xp7)
print("Neg7 =",P_corr_xn7)
# Out:
# 0.3333333206153529
# Pos1 = 0.410372055038906
# Neg1 = 0.7108481730472096
# Pos2 = 0.8331050933619802
# Neg2 = 0.25272737260085815
# Pos3 = 2.380260098893898
# Neg3 = 0.24312882032543556
# Pos4 = 8.538938715808678
# Neg4 = 0.40829019044691717
# Pos5 = 34.83730354140524
# Neg5 = 1.0424318476375563
# Pos6 = 148.22624170032887
# Neg6 = 3.6519499323520814
# Pos7 = 612.0064043983075
# Neg7 = 15.9234285483821

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1 = cube[12:14, 50:80, 50:65]
sub_cube1_vp1 = cube[13:15, 50:80, 50:65]
sub_cube1_vn1 = cube[11:13, 50:80, 50:65]

sub_cube2 = cube[14:16, 80:110, 50:65]
sub_cube2_vp1 = cube[15:17, 80:110, 50:65]
sub_cube2_vn1 = cube[13:15, 80:110, 50:65]

sub_cube3 = cube[16:18, 110:140, 50:65]
sub_cube3_vp1 = cube[17:19, 110:140, 50:65]
sub_cube3_vn1 = cube[15:17, 110:140, 50:65]

sub_cube4 = cube[18:20, 140:170, 50:65]
sub_cube4_vp1 = cube[19:21, 140:170, 50:65]
sub_cube4_vn1 = cube[17:19, 140:170, 50:65]

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1 = np.average(sub_cube1)
a1_vp1 = np.average(sub_cube1_vp1)
a1_vn1 = np.average(sub_cube1_vn1)

a2 = np.average(sub_cube2)
a2_vp1 = np.average(sub_cube2_vp1)
a2_vn1 = np.average(sub_cube2_vn1)

a3 = np.average(sub_cube3)
a3_vp1 = np.average(sub_cube3_vp1)
a3_vn1 = np.average(sub_cube3_vn1)

a4 = np.average(sub_cube4)
a4_vp1 = np.average(sub_cube4_vp1)
a4_vn1 = np.average(sub_cube4_vn1)

sum = a1 + a2 + a3 + a4
sum_vp1 = a1_vp1 + a2_vp1 + a3_vp1 + a4_vp1
sum_vn1 = a1_vn1 + a2_vn1 + a3_vn1 + a4_vn1

print("Sum = ", sum)
print("Sum_vp1 = ", sum_vp1)
print("Sum_vn1 = ", sum_vn1)

diff_sigma = (sum * 5.7) / 0.00046608012
diff_sigma_vp1 = (sum_vp1 * 5.7) / 0.00046608012
diff_sigma_vn1 = (sum_vn1 * 5.7) / 0.00046608012

print("Sigma p0 = ", diff_sigma)
print("Sigma vp1 = ", diff_sigma_vp1)
print("Sigma vn1 = ", diff_sigma_vn1)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1 = cube[12:14, 50:80, 50:65]
sub_cube1_yp2 = cube[12:14, 52:82, 50:65]
sub_cube1_yp4 = cube[12:14, 54:84, 50:65]
sub_cube1_yp6 = cube[12:14, 56:86, 50:65]
sub_cube1_yp8 = cube[12:14, 58:88, 50:65]
sub_cube1_yp10 = cube[12:14, 60:90, 50:65]
sub_cube1_yp12 = cube[12:14, 62:92, 50:65]
sub_cube1_yp14 = cube[12:14, 64:94, 50:65]
sub_cube1_yn2 = cube[12:14, 48:78, 50:65]
sub_cube1_yn4 = cube[12:14, 46:76, 50:65]
sub_cube1_yn6 = cube[12:14, 44:74, 50:65]
sub_cube1_yn8 = cube[12:14, 42:72, 50:65]
sub_cube1_yn10 = cube[12:14, 40:70, 50:65]
sub_cube1_yn12 = cube[12:14, 38:68, 50:65]
sub_cube1_yn14 = cube[12:14, 36:66, 50:65]

sub_cube2 = cube[14:16, 80:110, 50:65]
sub_cube2_yp2 = cube[14:16, 82:112, 50:65]
sub_cube2_yp4 = cube[14:16, 84:114, 50:65]
sub_cube2_yp6 = cube[14:16, 86:116, 50:65]
sub_cube2_yp8 = cube[14:16, 88:118, 50:65]
sub_cube2_yp10 = cube[14:16, 90:120, 50:65]
sub_cube2_yp12 = cube[14:16, 92:122, 50:65]
sub_cube2_yp14 = cube[14:16, 94:124, 50:65]
sub_cube2_yn2 = cube[14:16, 78:108, 50:65]
sub_cube2_yn4 = cube[14:16, 76:106, 50:65]
sub_cube2_yn6 = cube[14:16, 74:104, 50:65]
sub_cube2_yn8 = cube[14:16, 72:102, 50:65]
sub_cube2_yn10 = cube[14:16, 70:100, 50:65]
sub_cube2_yn12 = cube[14:16, 68:98, 50:65]
sub_cube2_yn14 = cube[14:16, 66:96, 50:65]

sub_cube3 = cube[16:18, 110:140, 50:65]
sub_cube3_yp2 = cube[16:18, 112:142, 50:65]
sub_cube3_yp4 = cube[16:18, 114:144, 50:65]
sub_cube3_yp6 = cube[16:18, 116:146, 50:65]
sub_cube3_yp8 = cube[16:18, 118:148, 50:65]
sub_cube3_yp10 = cube[16:18, 120:150, 50:65]
sub_cube3_yp12 = cube[16:18, 122:152, 50:65]
sub_cube3_yp14 = cube[16:18, 124:154, 50:65]
sub_cube3_yn2 = cube[16:18, 108:138, 50:65]
sub_cube3_yn4 = cube[16:18, 106:136, 50:65]
sub_cube3_yn6 = cube[16:18, 104:134, 50:65]
sub_cube3_yn8 = cube[16:18, 102:132, 50:65]
sub_cube3_yn10 = cube[16:18, 100:130, 50:65]
sub_cube3_yn12 = cube[16:18, 98:128, 50:65]
sub_cube3_yn14 = cube[16:18, 96:126, 50:65]

sub_cube4 = cube[18:20, 140:170, 50:65]
sub_cube4_yp2 = cube[18:20, 142:172, 50:65]
sub_cube4_yp4 = cube[18:20, 144:174, 50:65]
sub_cube4_yp6 = cube[18:20, 146:176, 50:65]
sub_cube4_yp8 = cube[18:20, 148:178, 50:65]
sub_cube4_yp10 = cube[18:20, 150:180, 50:65]
sub_cube4_yp12 = cube[18:20, 152:182, 50:65]
sub_cube4_yp14 = cube[18:20, 154:184, 50:65]
sub_cube4_yn2 = cube[18:20, 138:168, 50:65]
sub_cube4_yn4 = cube[18:20, 136:166, 50:65]
sub_cube4_yn6 = cube[18:20, 134:164, 50:65]
sub_cube4_yn8 = cube[18:20, 132:162, 50:65]
sub_cube4_yn10 = cube[18:20, 130:160, 50:65]
sub_cube4_yn12 = cube[18:20, 128:158, 50:65]
sub_cube4_yn14 = cube[18:20, 126:156, 50:65]


for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1 = np.average(sub_cube1)
a1_yp2 = np.average(sub_cube1_yp2)
a1_yp4 = np.average(sub_cube1_yp4)
a1_yp6 = np.average(sub_cube1_yp6)
a1_yp8 = np.average(sub_cube1_yp8)
a1_yp10 = np.average(sub_cube1_yp10)
a1_yp12 = np.average(sub_cube1_yp12)
a1_yp14 = np.average(sub_cube1_yp14)
a1_yn2 = np.average(sub_cube1_yn2)
a1_yn4 = np.average(sub_cube1_yn4)
a1_yn6 = np.average(sub_cube1_yn6)
a1_yn8 = np.average(sub_cube1_yn8)
a1_yn10 = np.average(sub_cube1_yn10)
a1_yn12 = np.average(sub_cube1_yn12)
a1_yn14 = np.average(sub_cube1_yn14)

a2 = np.average(sub_cube2)
a2_yp2 = np.average(sub_cube2_yp2)
a2_yp4 = np.average(sub_cube2_yp4)
a2_yp6 = np.average(sub_cube2_yp6)
a2_yp8 = np.average(sub_cube2_yp8)
a2_yp10 = np.average(sub_cube2_yp10)
a2_yp12 = np.average(sub_cube2_yp12)
a2_yp14 = np.average(sub_cube2_yp14)
a2_yn2 = np.average(sub_cube2_yn2)
a2_yn4 = np.average(sub_cube2_yn4)
a2_yn6 = np.average(sub_cube2_yn6)
a2_yn8 = np.average(sub_cube2_yn8)
a2_yn10 = np.average(sub_cube2_yn10)
a2_yn12 = np.average(sub_cube2_yn12)
a2_yn14 = np.average(sub_cube2_yn14)

a3 = np.average(sub_cube3)
a3_yp2 = np.average(sub_cube3_yp2)
a3_yp4 = np.average(sub_cube3_yp4)
a3_yp6 = np.average(sub_cube3_yp6)
a3_yp8 = np.average(sub_cube3_yp8)
a3_yp10 = np.average(sub_cube3_yp10)
a3_yp12 = np.average(sub_cube3_yp12)
a3_yp14 = np.average(sub_cube3_yp14)
a3_yn2 = np.average(sub_cube3_yn2)
a3_yn4 = np.average(sub_cube3_yn4)
a3_yn6 = np.average(sub_cube3_yn6)
a3_yn8 = np.average(sub_cube3_yn8)
a3_yn10 = np.average(sub_cube3_yn10)
a3_yn12 = np.average(sub_cube3_yn12)
a3_yn14 = np.average(sub_cube3_yn14)

a4 = np.average(sub_cube4)
a4_yp2 = np.average(sub_cube4_yp2)
a4_yp4 = np.average(sub_cube4_yp4)
a4_yp6 = np.average(sub_cube4_yp6)
a4_yp8 = np.average(sub_cube4_yp8)
a4_yp10 = np.average(sub_cube4_yp10)
a4_yp12 = np.average(sub_cube4_yp12)
a4_yp14 = np.average(sub_cube4_yp14)
a4_yn2 = np.average(sub_cube4_yn2)
a4_yn4 = np.average(sub_cube4_yn4)
a4_yn6 = np.average(sub_cube4_yn6)
a4_yn8 = np.average(sub_cube4_yn8)
a4_yn10 = np.average(sub_cube4_yn10)
a4_yn12 = np.average(sub_cube4_yn12)
a4_yn14 = np.average(sub_cube4_yn14)




sum = a1 + a2 + a3 + a4
sum_yp2 = a1_yp2 + a2_yp2 + a3_yp2 + a4_yp2
sum_yp4 = a1_yp4 + a2_yp4 + a3_yp4 + a4_yp4
sum_yp6 = a1_yp6 + a2_yp6 + a3_yp6 + a4_yp6
sum_yp8 = a1_yp8 + a2_yp8 + a3_yp8 + a4_yp8
sum_yp10 = a1_yp10 + a2_yp10 + a3_yp10 + a4_yp10
sum_yp12 = a1_yp12 + a2_yp12 + a3_yp12 + a4_yp12
sum_yp14 = a1_yp14 + a2_yp14 + a3_yp14 + a4_yp14
sum_yn2 = a1_yn2 + a2_yn2 + a3_yn2 + a4_yn2
sum_yn4 = a1_yn4 + a2_yn4 + a3_yn4 + a4_yn4
sum_yn6 = a1_yn6 + a2_yn6 + a3_yn6 + a4_yn6
sum_yn8 = a1_yn8 + a2_yn8 + a3_yn8 + a4_yn8
sum_yn10 = a1_yn10 + a2_yn10 + a3_yn10 + a4_yn10
sum_yn12 = a1_yn12 + a2_yn12 + a3_yn12 + a4_yn12
sum_yn14 = a1_yn14 + a2_yn14 + a3_yn14 + a4_yn14

print("Sum = ", sum)
print("Sum_yp1 = ", sum_yp2)
print("Sum_yn1 = ", sum_yn2)
print("Sum_yp2 = ", sum_yp4)
print("Sum_yn2 = ", sum_yn4)
print("Sum_yp3 = ", sum_yp6)
print("Sum_yn3 = ", sum_yn6)
print("Sum_yp4 = ", sum_yp8)
print("Sum_yn4 = ", sum_yn8)
print("Sum_yp5 = ", sum_yp10)
print("Sum_yn5 = ", sum_yn10)
print("Sum_yp6 = ", sum_yp12)
print("Sum_yn6 = ", sum_yn12)
print("Sum_yp7 = ", sum_yp14)
print("Sum_yn7 = ", sum_yn14)

diff_sigma = (sum * 5.7) / 0.00046608012
diff_sigma_yp2 = (sum_yp2 * 5.7) / 0.00046608012
diff_sigma_yn2 = (sum_yn2 * 5.7) / 0.00046608012
diff_sigma_yp4 = (sum_yp4 * 5.7) / 0.00046608012
diff_sigma_yn4 = (sum_yn4 * 5.7) / 0.00046608012
diff_sigma_yp6 = (sum_yp6 * 5.7) / 0.00046608012
diff_sigma_yn6 = (sum_yn6 * 5.7) / 0.00046608012
diff_sigma_yp8 = (sum_yp8 * 5.7) / 0.00046608012
diff_sigma_yn8 = (sum_yn8 * 5.7) / 0.00046608012
diff_sigma_yp10 = (sum_yp10 * 5.7) / 0.00046608012
diff_sigma_yn10 = (sum_yn10 * 5.7) / 0.00046608012
diff_sigma_yp12 = (sum_yp12 * 5.7) / 0.00046608012
diff_sigma_yn12 = (sum_yn12 * 5.7) / 0.00046608012
diff_sigma_yp14 = (sum_yp14 * 5.7) / 0.00046608012
diff_sigma_yn14 = (sum_yn14 * 5.7) / 0.00046608012


print("Sigma p0 = ", diff_sigma)
print("Sigma yp2 = ", diff_sigma_yp2)
print("Sigma yn2 = ", diff_sigma_yn2)
print("Sigma yp4 = ", diff_sigma_yp4)
print("Sigma yn4 = ", diff_sigma_yn4)
print("Sigma yp6 = ", diff_sigma_yp6)
print("Sigma yn6 = ", diff_sigma_yn6)
print("Sigma yp8 = ", diff_sigma_yp8)
print("Sigma yn8 = ", diff_sigma_yn8)
print("Sigma yp10 = ", diff_sigma_yp10)
print("Sigma yn10 = ", diff_sigma_yn10)
print("Sigma yp12 = ", diff_sigma_yp12)
print("Sigma yn12 = ", diff_sigma_yn12)
print("Sigma yp14 = ", diff_sigma_yp14)
print("Sigma yn14 = ", diff_sigma_yn14)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...

# %%
import scipy.stats

P_norm = scipy.stats.norm.sf(abs(5.7))

P_stat = scipy.stats.norm.sf(abs(diff_sigma))
P_stat_yp2 = scipy.stats.norm.sf(abs(diff_sigma_yp2))
P_stat_yn2 = scipy.stats.norm.sf(abs(diff_sigma_yn2))
P_stat_yp4 = scipy.stats.norm.sf(abs(diff_sigma_yp4))
P_stat_yn4 = scipy.stats.norm.sf(abs(diff_sigma_yn4))
P_stat_yp6 = scipy.stats.norm.sf(abs(diff_sigma_yp6))
P_stat_yn6 = scipy.stats.norm.sf(abs(diff_sigma_yn6))
P_stat_yp8 = scipy.stats.norm.sf(abs(diff_sigma_yp8))
P_stat_yn8 = scipy.stats.norm.sf(abs(diff_sigma_yn8))
P_stat_yp10 = scipy.stats.norm.sf(abs(diff_sigma_yp10))
P_stat_yn10 = scipy.stats.norm.sf(abs(diff_sigma_yn10))
P_stat_yp12 = scipy.stats.norm.sf(abs(diff_sigma_yp12))
P_stat_yn12 = scipy.stats.norm.sf(abs(diff_sigma_yn12))
P_stat_yp14 = scipy.stats.norm.sf(abs(diff_sigma_yp14))
P_stat_yn14 = scipy.stats.norm.sf(abs(diff_sigma_yn14))

P_corr = P_stat / P_norm
P_corr_yp2 = P_stat_yp2 / (5 * P_norm)
P_corr_yn2 = P_stat_yn2 / (5 * P_norm)
P_corr_yp4 = P_stat_yp4 / (9 * P_norm)
P_corr_yn4 = P_stat_yn4 / (9 * P_norm)
P_corr_yp6 = P_stat_yp6 / (13 * P_norm)
P_corr_yn6 = P_stat_yn6 / (13 * P_norm)
P_corr_yp8 = P_stat_yp8 / (17 * P_norm)
P_corr_yn8 = P_stat_yn8 / (17 * P_norm)
P_corr_yp10 = P_stat_yp10 / (21 * P_norm)
P_corr_yn10 = P_stat_yn10 / (21 * P_norm)
P_corr_yp12 = P_stat_yp12 / (25 * P_norm)
P_corr_yn12 = P_stat_yn12 / (25 * P_norm)
P_corr_yp14 = P_stat_yp14 / (29 * P_norm)
P_corr_yn14 = P_stat_yn14 / (29 * P_norm)

print(P_corr)
print("Pos2 =",P_corr_yp2)
print("Neg2 =",P_corr_yn2)
print("Pos4 =",P_corr_yp4)
print("Neg4 =",P_corr_yn4)
print("Pos6 =",P_corr_yp6)
print("Neg6 =",P_corr_yn6)
print("Pos8 =",P_corr_yp8)
print("Neg8 =",P_corr_yn8)
print("Pos10 =",P_corr_yp10)
print("Neg10 =",P_corr_yn10)
print("Pos12 =",P_corr_yp12)
print("Neg12 =",P_corr_yn12)
print("Pos14 =",P_corr_yp14)
print("Neg14 =",P_corr_yn14)
# Out:
# 0.9999999618460587
# Pos2 = 0.2160234079776479
# Neg2 = 0.28283714125023546
# Pos4 = 0.19143826926555194
# Neg4 = 0.33758223663680625
# Pos6 = 0.29546826500674145
# Neg6 = 0.7223091195849736
# Pos8 = 0.6632542559722023
# Neg8 = 2.223489679063432
# Pos10 = 1.9651993407246802
# Neg10 = 8.324132763490734
# Pos12 = 7.174014458194296
# Neg12 = 32.773881827227406
# Pos14 = 30.375603944155838
# Neg14 = 121.32859885467943

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1 = cube[12:14, 50:80, 50:65]
sub_cube1_rp1 = cube[12:14, 50:80, 50:65]
sub_cube1_rp2 = cube[12:14, 50:80, 50:65]
sub_cube1_rp3 = cube[12:14, 50:80, 50:65]
sub_cube1_rp4 = cube[12:14, 50:80, 50:65]
sub_cube1_rp5 = cube[12:14, 50:80, 50:65]
sub_cube1_rp10 = cube[12:14, 50:80, 50:65]
sub_cube1_rp15 = cube[12:14, 50:80, 50:65]
sub_cube1_rp20 = cube[12:14, 50:80, 50:65]
sub_cube1_rn1 = cube[12:14, 50:80, 50:65]
sub_cube1_rn2 = cube[12:14, 50:80, 50:65]
sub_cube1_rn3 = cube[12:14, 50:80, 50:65]
sub_cube1_rn4 = cube[12:14, 50:80, 50:65]
sub_cube1_rn5 = cube[12:14, 50:80, 50:65]
sub_cube1_rn10 = cube[12:14, 50:80, 50:65]
sub_cube1_rn15 = cube[12:14, 50:80, 50:65]
sub_cube1_rn20 = cube[12:14, 50:80, 50:65]

sub_cube2 = cube[14:16, 80:110, 50:65]
sub_cube2_rp1 = cube[14:16, 80:110, 50:65]
sub_cube2_rp2 = cube[14:16, 80:110, 51:66]
sub_cube2_rp3 = cube[14:16, 80:110, 52:67]
sub_cube2_rp4 = cube[14:16, 80:110, 52:67]
sub_cube2_rp5 = cube[14:16, 80:110, 53:68]
sub_cube2_rp10 = cube[14:16, 80:110, 57:72]
sub_cube2_rp15 = cube[14:16, 80:110, 60:75]
sub_cube2_rp20 = cube[14:16, 80:110, 64:79]
sub_cube2_rn1 = cube[14:16, 80:110, 50:65]
sub_cube2_rn2 = cube[14:16, 80:110, 49:64]
sub_cube2_rn3 = cube[14:16, 80:110, 48:63]
sub_cube2_rn4 = cube[14:16, 80:110, 48:63]
sub_cube2_rn5 = cube[14:16, 80:110, 47:62]
sub_cube2_rn10 = cube[14:16, 80:110, 43:58]
sub_cube2_rn15 = cube[14:16, 80:110, 40:55]
sub_cube2_rn20 = cube[14:16, 80:110, 36:51]

sub_cube3 = cube[16:18, 110:140, 50:65]
sub_cube3_rp1 = cube[16:18, 110:140, 51:66]
sub_cube3_rp2 = cube[16:18, 110:140, 52:67]
sub_cube3_rp3 = cube[16:18, 110:140, 54:69]
sub_cube3_rp4 = cube[16:18, 110:140, 55:70]
sub_cube3_rp5 = cube[16:18, 110:140, 57:72]
sub_cube3_rp10 = cube[16:18, 110:140, 64:79]
sub_cube3_rp15 = cube[16:18, 110:140, 71:86]
sub_cube3_rp20 = cube[16:18, 110:140, 79:94]
sub_cube3_rn1 = cube[16:18, 110:140, 49:64]
sub_cube3_rn2 = cube[16:18, 110:140, 48:63]
sub_cube3_rn3 = cube[16:18, 110:140, 46:61]
sub_cube3_rn4 = cube[16:18, 110:140, 45:60]
sub_cube3_rn5 = cube[16:18, 110:140, 43:58]
sub_cube3_rn10 = cube[16:18, 110:140, 36:51]
sub_cube3_rn15 = cube[16:18, 110:140, 29:44]
sub_cube3_rn20 = cube[16:18, 110:140, 21:36]

sub_cube4 = cube[18:20, 140:170, 50:65]
sub_cube4_rp1 = cube[18:20, 140:170, 52:67]
sub_cube4_rp2 = cube[18:20, 140:170, 54:69]
sub_cube4_rp3 = cube[18:20, 140:170, 56:71]
sub_cube4_rp4 = cube[18:20, 140:170, 58:73]
sub_cube4_rp5 = cube[18:20, 140:170, 60:75]
sub_cube4_rp10 = cube[18:20, 140:170, 71:86]
sub_cube4_rp15 = cube[18:20, 140:170, 82:97]
sub_cube4_rp20 = cube[18:20, 140:170, 94:109]
sub_cube4_rn1 = cube[18:20, 140:170, 48:63]
sub_cube4_rn2 = cube[18:20, 140:170, 46:61]
sub_cube4_rn3 = cube[18:20, 140:170, 44:59]
sub_cube4_rn4 = cube[18:20, 140:170, 42:57]
sub_cube4_rn5 = cube[18:20, 140:170, 40:55]
sub_cube4_rn10 = cube[18:20, 140:170, 29:44]
sub_cube4_rn15 = cube[18:20, 140:170, 18:97]
sub_cube4_rn20 = cube[18:20, 140:170, 6:21]

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1 = np.average(sub_cube1)
a1_rp1 = np.average(sub_cube1_rp1)
a1_rp2 = np.average(sub_cube1_rp2)
a1_rp3 = np.average(sub_cube1_rp3)
a1_rp4 = np.average(sub_cube1_rp4)
a1_rp5 = np.average(sub_cube1_rp5)
a1_rp10 = np.average(sub_cube1_rp10)
a1_rp15 = np.average(sub_cube1_rp15)
a1_rp20 = np.average(sub_cube1_rp20)
a1_rn1 = np.average(sub_cube1_rn1)
a1_rn2 = np.average(sub_cube1_rn2)
a1_rn3 = np.average(sub_cube1_rn3)
a1_rn4 = np.average(sub_cube1_rn4)
a1_rn5 = np.average(sub_cube1_rn5)
a1_rn10 = np.average(sub_cube1_rn10)
a1_rn15 = np.average(sub_cube1_rn15)
a1_rn20 = np.average(sub_cube1_rn20)

a2 = np.average(sub_cube2)
a2_rp1 = np.average(sub_cube2_rp1)
a2_rp2 = np.average(sub_cube2_rp2)
a2_rp3 = np.average(sub_cube2_rp3)
a2_rp4 = np.average(sub_cube2_rp4)
a2_rp5 = np.average(sub_cube2_rp5)
a2_rp10 = np.average(sub_cube2_rp10)
a2_rp15 = np.average(sub_cube2_rp15)
a2_rp20 = np.average(sub_cube2_rp20)
a2_rn1 = np.average(sub_cube2_rn1)
a2_rn2 = np.average(sub_cube2_rn2)
a2_rn3 = np.average(sub_cube2_rn3)
a2_rn4 = np.average(sub_cube2_rn4)
a2_rn5 = np.average(sub_cube2_rn5)
a2_rn10 = np.average(sub_cube2_rn10)
a2_rn15 = np.average(sub_cube2_rn15)
a2_rn20 = np.average(sub_cube2_rn20)

a3 = np.average(sub_cube3)
a3_rp1 = np.average(sub_cube3_rp1)
a3_rp2 = np.average(sub_cube3_rp2)
a3_rp3 = np.average(sub_cube3_rp3)
a3_rp4 = np.average(sub_cube3_rp4)
a3_rp5 = np.average(sub_cube3_rp5)
a3_rp10 = np.average(sub_cube3_rp10)
a3_rp15 = np.average(sub_cube3_rp15)
a3_rp20 = np.average(sub_cube3_rp20)
a3_rn1 = np.average(sub_cube3_rn1)
a3_rn2 = np.average(sub_cube3_rn2)
a3_rn3 = np.average(sub_cube3_rn3)
a3_rn4 = np.average(sub_cube3_rn4)
a3_rn5 = np.average(sub_cube3_rn5)
a3_rn10 = np.average(sub_cube3_rn10)
a3_rn15 = np.average(sub_cube3_rn15)
a3_rn20 = np.average(sub_cube3_rn20)

a4 = np.average(sub_cube4)
a4_rp1 = np.average(sub_cube4_rp1)
a4_rp2 = np.average(sub_cube4_rp2)
a4_rp3 = np.average(sub_cube4_rp3)
a4_rp4 = np.average(sub_cube4_rp4)
a4_rp5 = np.average(sub_cube4_rp5)
a4_rp10 = np.average(sub_cube4_rp10)
a4_rp15 = np.average(sub_cube4_rp15)
a4_rp20 = np.average(sub_cube4_rp20)
a4_rn1 = np.average(sub_cube4_rn1)
a4_rn2 = np.average(sub_cube4_rn2)
a4_rn3 = np.average(sub_cube4_rn3)
a4_rn4 = np.average(sub_cube4_rn4)
a4_rn5 = np.average(sub_cube4_rn5)
a4_rn10 = np.average(sub_cube4_rn10)
a4_rn15 = np.average(sub_cube4_rn15)
a4_rn20 = np.average(sub_cube4_rn20)


sum = a1 + a2 + a3 + a4
sum_rp1 = a1_rp1 + a2_rp1 + a3_rp1 + a4_rp1
sum_rp2 = a1_rp2 + a2_rp2 + a3_rp2 + a4_rp2
sum_rp3 = a1_rp3 + a2_rp3 + a3_rp3 + a4_rp3
sum_rp4 = a1_rp4 + a2_rp4 + a3_rp4 + a4_rp4
sum_rp5 = a1_rp5 + a2_rp5 + a3_rp5 + a4_rp5
sum_rp10 = a1_rp10 + a2_rp10 + a3_rp10 + a4_rp10
sum_rp15 = a1_rp15 + a2_rp15 + a3_rp15 + a4_rp15
sum_rp20 = a1_rp20 + a2_rp20 + a3_rp20 + a4_rp20
sum_rn1 = a1_rn1 + a2_rn1 + a3_rn1 + a4_rn1
sum_rn2 = a1_rn2 + a2_rn2 + a3_rn2 + a4_rn2
sum_rn3 = a1_rn3 + a2_rn3 + a3_rn3 + a4_rn3
sum_rn4 = a1_rn4 + a2_rn4 + a3_rn4 + a4_rn4
sum_rn5 = a1_rn5 + a2_rn5 + a3_rn5 + a4_rn5
sum_rn10 = a1_rn10 + a2_rn10 + a3_rn10 + a4_rn10
sum_rn15 = a1_rn15 + a2_rn15 + a3_rn15 + a4_rn15
sum_rn20 = a1_rn20 + a2_rn20 + a3_rn20 + a4_rn20

print("Sum = ", sum)
print("Sum_rp1 = ", sum_rp1)
print("Sum_rn1 = ", sum_rn1)
print("Sum_rp2 = ", sum_rp2)
print("Sum_rn2 = ", sum_rn2)
print("Sum_rp3 = ", sum_rp3)
print("Sum_rn3 = ", sum_rn3)
print("Sum_rp4 = ", sum_rp4)
print("Sum_rn4 = ", sum_rn4)
print("Sum_rp5 = ", sum_rp5)
print("Sum_rn5 = ", sum_rn5)
print("Sum_rp10 = ", sum_rp10)
print("Sum_rn10 = ", sum_rn10)
print("Sum_rp15 = ", sum_rp15)
print("Sum_rn15 = ", sum_rn15)
print("Sum_rp20 = ", sum_rp20)
print("Sum_rn20 = ", sum_rn20)

diff_sigma = (sum * 5.7) / 0.00046608012
diff_sigma_rp1 = (sum_rp1 * 5.7) / 0.00046608012
diff_sigma_rn1 = (sum_rn1 * 5.7) / 0.00046608012
diff_sigma_rp2 = (sum_rp2 * 5.7) / 0.00046608012
diff_sigma_rn2 = (sum_rn2 * 5.7) / 0.00046608012
diff_sigma_rp3 = (sum_rp3 * 5.7) / 0.00046608012
diff_sigma_rn3 = (sum_rn3 * 5.7) / 0.00046608012
diff_sigma_rp4 = (sum_rp4 * 5.7) / 0.00046608012
diff_sigma_rn4 = (sum_rn4 * 5.7) / 0.00046608012
diff_sigma_rp5 = (sum_rp5 * 5.7) / 0.00046608012
diff_sigma_rn5 = (sum_rn5 * 5.7) / 0.00046608012
diff_sigma_rp10 = (sum_rp10 * 5.7) / 0.00046608012
diff_sigma_rn10 = (sum_rn10 * 5.7) / 0.00046608012
diff_sigma_rp15 = (sum_rp15 * 5.7) / 0.00046608012
diff_sigma_rn15 = (sum_rn15 * 5.7) / 0.00046608012
diff_sigma_rp20 = (sum_rp20 * 5.7) / 0.00046608012
diff_sigma_rn20 = (sum_rn20 * 5.7) / 0.00046608012

print("Sigma p0 = ", diff_sigma)
print("Sigma rp1 = ", diff_sigma_rp1)
print("Sigma rn1 = ", diff_sigma_rn1)
print("Sigma rp2 = ", diff_sigma_rp2)
print("Sigma rn2 = ", diff_sigma_rn2)
print("Sigma rp3 = ", diff_sigma_rp3)
print("Sigma rn3 = ", diff_sigma_rn3)
print("Sigma rp4 = ", diff_sigma_rp4)
print("Sigma rn4 = ", diff_sigma_rn4)
print("Sigma rp5 = ", diff_sigma_rp5)
print("Sigma rn5 = ", diff_sigma_rn5)
print("Sigma rp10 = ", diff_sigma_rp10)
print("Sigma rn10 = ", diff_sigma_rn10)
print("Sigma rp15 = ", diff_sigma_rp15)
print("Sigma rn15 = ", diff_sigma_rn15)
print("Sigma rp20 = ", diff_sigma_rp20)
print("Sigma rn20 = ", diff_sigma_rn20)

P_norm = scipy.stats.norm.sf(abs(5.7))

P_stat = scipy.stats.norm.sf(abs(diff_sigma))
P_stat_rp1 = scipy.stats.norm.sf(abs(diff_sigma_rp1))
P_stat_rn1 = scipy.stats.norm.sf(abs(diff_sigma_rn1))
P_stat_rp2 = scipy.stats.norm.sf(abs(diff_sigma_rp2))
P_stat_rn2 = scipy.stats.norm.sf(abs(diff_sigma_rn2))
P_stat_rp3 = scipy.stats.norm.sf(abs(diff_sigma_rp3))
P_stat_rn3 = scipy.stats.norm.sf(abs(diff_sigma_rn3))
P_stat_rp4 = scipy.stats.norm.sf(abs(diff_sigma_rp4))
P_stat_rn4 = scipy.stats.norm.sf(abs(diff_sigma_rn4))
P_stat_rp5 = scipy.stats.norm.sf(abs(diff_sigma_rp5))
P_stat_rn5 = scipy.stats.norm.sf(abs(diff_sigma_rn5))
P_stat_rp10 = scipy.stats.norm.sf(abs(diff_sigma_rp10))
P_stat_rn10 = scipy.stats.norm.sf(abs(diff_sigma_rn10))
P_stat_rp15 = scipy.stats.norm.sf(abs(diff_sigma_rp15))
P_stat_rn15 = scipy.stats.norm.sf(abs(diff_sigma_rn15))
P_stat_rp20 = scipy.stats.norm.sf(abs(diff_sigma_rp20))
P_stat_rn20 = scipy.stats.norm.sf(abs(diff_sigma_rn20))

P_corr = P_stat / P_norm
P_corr_rp1 = P_stat_rp1 / (5 * P_norm)
P_corr_rn1 = P_stat_rn1 / (5 * P_norm)
P_corr_rp2 = P_stat_rp2 / (9 * P_norm)
P_corr_rn2 = P_stat_rn2 / (9 * P_norm)
P_corr_rp3 = P_stat_rp3 / (13 * P_norm)
P_corr_rn3 = P_stat_rn3 / (13 * P_norm)
P_corr_rp4 = P_stat_rp4 / (13 * P_norm)
P_corr_rn4 = P_stat_rn4 / (13 * P_norm)
P_corr_rp5 = P_stat_rp5 / (13 * P_norm)
P_corr_rn5 = P_stat_rn5 / (13 * P_norm)
P_corr_rp10 = P_stat_rp10 / (13 * P_norm)
P_corr_rn10 = P_stat_rn10 / (13 * P_norm)
P_corr_rp15 = P_stat_rp15 / (13 * P_norm)
P_corr_rn15 = P_stat_rn15 / (13 * P_norm)
P_corr_rp20 = P_stat_rp20 / (13 * P_norm)
P_corr_rn20 = P_stat_rn20 / (13 * P_norm)

print(P_corr)
print("Pos1 =",P_corr_rp1)
print("Neg1 =",P_corr_rn1)
print("Pos2 =",P_corr_rp2)
print("Neg2 =",P_corr_rn2)
print("Pos3 =",P_corr_rp3)
print("Neg3 =",P_corr_rn3)
print("Pos4 =",P_corr_rp4)
print("Neg4 =",P_corr_rn4)
print("Pos5 =",P_corr_rp5)
print("Neg5 =",P_corr_rn5)
print("Pos10 =",P_corr_rp10)
print("Neg10 =",P_corr_rn10)
print("Pos15 =",P_corr_rp15)
print("Neg15 =",P_corr_rn15)
print("Pos20 =",P_corr_rp20)
print("Neg20 =",P_corr_rn20)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1 = cube[12:14, 50:80, 50:65]
sub_cube1_yp2 = cube[12:14, 52:82, 50:65]
sub_cube1_yp4 = cube[12:14, 54:84, 50:65]
sub_cube1_yp6 = cube[12:14, 56:86, 50:65]
sub_cube1_yp8 = cube[12:14, 58:88, 50:65]
sub_cube1_yp10 = cube[13:15, 60:90, 50:65]
sub_cube1_yp12 = cube[13:15, 62:92, 50:65]
sub_cube1_yp14 = cube[13:15, 64:94, 50:65]
sub_cube1_yn2 = cube[12:14, 48:78, 50:65]
sub_cube1_yn4 = cube[12:14, 46:76, 50:65]
sub_cube1_yn6 = cube[12:14, 44:74, 50:65]
sub_cube1_yn8 = cube[12:14, 42:72, 50:65]
sub_cube1_yn10 = cube[11:13, 40:70, 50:65]
sub_cube1_yn12 = cube[11:13, 38:68, 50:65]
sub_cube1_yn14 = cube[11:13, 36:66, 50:65]

sub_cube2 = cube[14:16, 80:110, 50:65]
sub_cube2_yp2 = cube[14:16, 82:112, 50:65]
sub_cube2_yp4 = cube[14:16, 84:114, 50:65]
sub_cube2_yp6 = cube[14:16, 86:116, 50:65]
sub_cube2_yp8 = cube[14:16, 88:118, 50:65]
sub_cube2_yp10 = cube[15:17, 90:120, 50:65]
sub_cube2_yp12 = cube[15:17, 92:122, 50:65]
sub_cube2_yp14 = cube[15:17, 94:124, 50:65]
sub_cube2_yn2 = cube[14:16, 78:108, 50:65]
sub_cube2_yn4 = cube[14:16, 76:106, 50:65]
sub_cube2_yn6 = cube[14:16, 74:104, 50:65]
sub_cube2_yn8 = cube[14:16, 72:102, 50:65]
sub_cube2_yn10 = cube[13:15, 70:100, 50:65]
sub_cube2_yn12 = cube[13:15, 68:98, 50:65]
sub_cube2_yn14 = cube[13:15, 66:96, 50:65]

sub_cube3 = cube[16:18, 110:140, 50:65]
sub_cube3_yp2 = cube[16:18, 112:142, 50:65]
sub_cube3_yp4 = cube[16:18, 114:144, 50:65]
sub_cube3_yp6 = cube[16:18, 116:146, 50:65]
sub_cube3_yp8 = cube[16:18, 118:148, 50:65]
sub_cube3_yp10 = cube[17:19, 120:150, 50:65]
sub_cube3_yp12 = cube[17:19, 122:152, 50:65]
sub_cube3_yp14 = cube[17:19, 124:154, 50:65]
sub_cube3_yn2 = cube[16:18, 108:138, 50:65]
sub_cube3_yn4 = cube[16:18, 106:136, 50:65]
sub_cube3_yn6 = cube[16:18, 104:134, 50:65]
sub_cube3_yn8 = cube[16:18, 102:132, 50:65]
sub_cube3_yn10 = cube[15:17, 100:130, 50:65]
sub_cube3_yn12 = cube[15:17, 98:128, 50:65]
sub_cube3_yn14 = cube[15:17, 96:126, 50:65]

sub_cube4 = cube[18:20, 140:170, 50:65]
sub_cube4_yp2 = cube[18:20, 142:172, 50:65]
sub_cube4_yp4 = cube[18:20, 144:174, 50:65]
sub_cube4_yp6 = cube[18:20, 146:176, 50:65]
sub_cube4_yp8 = cube[18:20, 148:178, 50:65]
sub_cube4_yp10 = cube[19:21, 150:180, 50:65]
sub_cube4_yp12 = cube[19:21, 152:182, 50:65]
sub_cube4_yp14 = cube[19:21, 154:184, 50:65]
sub_cube4_yn2 = cube[18:20, 138:168, 50:65]
sub_cube4_yn4 = cube[18:20, 136:166, 50:65]
sub_cube4_yn6 = cube[18:20, 134:164, 50:65]
sub_cube4_yn8 = cube[18:20, 132:162, 50:65]
sub_cube4_yn10 = cube[17:19, 130:160, 50:65]
sub_cube4_yn12 = cube[17:19, 128:158, 50:65]
sub_cube4_yn14 = cube[17:19, 126:156, 50:65]


for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1 = np.average(sub_cube1)
a1_yp2 = np.average(sub_cube1_yp2)
a1_yp4 = np.average(sub_cube1_yp4)
a1_yp6 = np.average(sub_cube1_yp6)
a1_yp8 = np.average(sub_cube1_yp8)
a1_yp10 = np.average(sub_cube1_yp10)
a1_yp12 = np.average(sub_cube1_yp12)
a1_yp14 = np.average(sub_cube1_yp14)
a1_yn2 = np.average(sub_cube1_yn2)
a1_yn4 = np.average(sub_cube1_yn4)
a1_yn6 = np.average(sub_cube1_yn6)
a1_yn8 = np.average(sub_cube1_yn8)
a1_yn10 = np.average(sub_cube1_yn10)
a1_yn12 = np.average(sub_cube1_yn12)
a1_yn14 = np.average(sub_cube1_yn14)

a2 = np.average(sub_cube2)
a2_yp2 = np.average(sub_cube2_yp2)
a2_yp4 = np.average(sub_cube2_yp4)
a2_yp6 = np.average(sub_cube2_yp6)
a2_yp8 = np.average(sub_cube2_yp8)
a2_yp10 = np.average(sub_cube2_yp10)
a2_yp12 = np.average(sub_cube2_yp12)
a2_yp14 = np.average(sub_cube2_yp14)
a2_yn2 = np.average(sub_cube2_yn2)
a2_yn4 = np.average(sub_cube2_yn4)
a2_yn6 = np.average(sub_cube2_yn6)
a2_yn8 = np.average(sub_cube2_yn8)
a2_yn10 = np.average(sub_cube2_yn10)
a2_yn12 = np.average(sub_cube2_yn12)
a2_yn14 = np.average(sub_cube2_yn14)

a3 = np.average(sub_cube3)
a3_yp2 = np.average(sub_cube3_yp2)
a3_yp4 = np.average(sub_cube3_yp4)
a3_yp6 = np.average(sub_cube3_yp6)
a3_yp8 = np.average(sub_cube3_yp8)
a3_yp10 = np.average(sub_cube3_yp10)
a3_yp12 = np.average(sub_cube3_yp12)
a3_yp14 = np.average(sub_cube3_yp14)
a3_yn2 = np.average(sub_cube3_yn2)
a3_yn4 = np.average(sub_cube3_yn4)
a3_yn6 = np.average(sub_cube3_yn6)
a3_yn8 = np.average(sub_cube3_yn8)
a3_yn10 = np.average(sub_cube3_yn10)
a3_yn12 = np.average(sub_cube3_yn12)
a3_yn14 = np.average(sub_cube3_yn14)

a4 = np.average(sub_cube4)
a4_yp2 = np.average(sub_cube4_yp2)
a4_yp4 = np.average(sub_cube4_yp4)
a4_yp6 = np.average(sub_cube4_yp6)
a4_yp8 = np.average(sub_cube4_yp8)
a4_yp10 = np.average(sub_cube4_yp10)
a4_yp12 = np.average(sub_cube4_yp12)
a4_yp14 = np.average(sub_cube4_yp14)
a4_yn2 = np.average(sub_cube4_yn2)
a4_yn4 = np.average(sub_cube4_yn4)
a4_yn6 = np.average(sub_cube4_yn6)
a4_yn8 = np.average(sub_cube4_yn8)
a4_yn10 = np.average(sub_cube4_yn10)
a4_yn12 = np.average(sub_cube4_yn12)
a4_yn14 = np.average(sub_cube4_yn14)




sum = a1 + a2 + a3 + a4
sum_yp2 = a1_yp2 + a2_yp2 + a3_yp2 + a4_yp2
sum_yp4 = a1_yp4 + a2_yp4 + a3_yp4 + a4_yp4
sum_yp6 = a1_yp6 + a2_yp6 + a3_yp6 + a4_yp6
sum_yp8 = a1_yp8 + a2_yp8 + a3_yp8 + a4_yp8
sum_yp10 = a1_yp10 + a2_yp10 + a3_yp10 + a4_yp10
sum_yp12 = a1_yp12 + a2_yp12 + a3_yp12 + a4_yp12
sum_yp14 = a1_yp14 + a2_yp14 + a3_yp14 + a4_yp14
sum_yn2 = a1_yn2 + a2_yn2 + a3_yn2 + a4_yn2
sum_yn4 = a1_yn4 + a2_yn4 + a3_yn4 + a4_yn4
sum_yn6 = a1_yn6 + a2_yn6 + a3_yn6 + a4_yn6
sum_yn8 = a1_yn8 + a2_yn8 + a3_yn8 + a4_yn8
sum_yn10 = a1_yn10 + a2_yn10 + a3_yn10 + a4_yn10
sum_yn12 = a1_yn12 + a2_yn12 + a3_yn12 + a4_yn12
sum_yn14 = a1_yn14 + a2_yn14 + a3_yn14 + a4_yn14

print("Sum = ", sum)
print("Sum_yp1 = ", sum_yp2)
print("Sum_yn1 = ", sum_yn2)
print("Sum_yp2 = ", sum_yp4)
print("Sum_yn2 = ", sum_yn4)
print("Sum_yp3 = ", sum_yp6)
print("Sum_yn3 = ", sum_yn6)
print("Sum_yp4 = ", sum_yp8)
print("Sum_yn4 = ", sum_yn8)
print("Sum_yp5 = ", sum_yp10)
print("Sum_yn5 = ", sum_yn10)
print("Sum_yp6 = ", sum_yp12)
print("Sum_yn6 = ", sum_yn12)
print("Sum_yp7 = ", sum_yp14)
print("Sum_yn7 = ", sum_yn14)

diff_sigma = (sum * 5.7) / 0.00046608012
diff_sigma_yp2 = (sum_yp2 * 5.7) / 0.00046608012
diff_sigma_yn2 = (sum_yn2 * 5.7) / 0.00046608012
diff_sigma_yp4 = (sum_yp4 * 5.7) / 0.00046608012
diff_sigma_yn4 = (sum_yn4 * 5.7) / 0.00046608012
diff_sigma_yp6 = (sum_yp6 * 5.7) / 0.00046608012
diff_sigma_yn6 = (sum_yn6 * 5.7) / 0.00046608012
diff_sigma_yp8 = (sum_yp8 * 5.7) / 0.00046608012
diff_sigma_yn8 = (sum_yn8 * 5.7) / 0.00046608012
diff_sigma_yp10 = (sum_yp10 * 5.7) / 0.00046608012
diff_sigma_yn10 = (sum_yn10 * 5.7) / 0.00046608012
diff_sigma_yp12 = (sum_yp12 * 5.7) / 0.00046608012
diff_sigma_yn12 = (sum_yn12 * 5.7) / 0.00046608012
diff_sigma_yp14 = (sum_yp14 * 5.7) / 0.00046608012
diff_sigma_yn14 = (sum_yn14 * 5.7) / 0.00046608012


print("Sigma p0 = ", diff_sigma)
print("Sigma yp2 = ", diff_sigma_yp2)
print("Sigma yn2 = ", diff_sigma_yn2)
print("Sigma yp4 = ", diff_sigma_yp4)
print("Sigma yn4 = ", diff_sigma_yn4)
print("Sigma yp6 = ", diff_sigma_yp6)
print("Sigma yn6 = ", diff_sigma_yn6)
print("Sigma yp8 = ", diff_sigma_yp8)
print("Sigma yn8 = ", diff_sigma_yn8)
print("Sigma yp10 = ", diff_sigma_yp10)
print("Sigma yn10 = ", diff_sigma_yn10)
print("Sigma yp12 = ", diff_sigma_yp12)
print("Sigma yn12 = ", diff_sigma_yn12)
print("Sigma yp14 = ", diff_sigma_yp14)
print("Sigma yn14 = ", diff_sigma_yn14)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1 = cube[12:14, 50:80, 50:65]
sub_cube1_rp1 = cube[12:14, 50:80, 50:65]
sub_cube1_rp2 = cube[12:14, 50:80, 50:65]
sub_cube1_rp3 = cube[12:14, 50:80, 50:65]
sub_cube1_rp4 = cube[12:14, 50:80, 50:65]
sub_cube1_rp5 = cube[12:14, 50:80, 50:65]
sub_cube1_rp6 = cube[12:14, 50:80, 50:65]
sub_cube1_rp8 = cube[12:14, 50:80, 50:65]
sub_cube1_rp10 = cube[12:14, 50:80, 50:65]
sub_cube1_rp12 = cube[12:14, 50:80, 50:65]
sub_cube1_rn1 = cube[12:14, 50:80, 50:65]
sub_cube1_rn2 = cube[12:14, 50:80, 50:65]
sub_cube1_rn3 = cube[12:14, 50:80, 50:65]
sub_cube1_rn4 = cube[12:14, 50:80, 50:65]
sub_cube1_rn5 = cube[12:14, 50:80, 50:65]
sub_cube1_rn6 = cube[12:14, 50:80, 50:65]
sub_cube1_rn8 = cube[12:14, 50:80, 50:65]
sub_cube1_rn10 = cube[12:14, 50:80, 50:65]
sub_cube1_rn12 = cube[12:14, 50:80, 50:65]

sub_cube2 = cube[14:16, 80:110, 50:65]
sub_cube2_rp1 = cube[14:16, 80:110, 50:65]
sub_cube2_rp2 = cube[14:16, 80:110, 51:66]
sub_cube2_rp3 = cube[14:16, 80:110, 51:66]
sub_cube2_rp4 = cube[14:16, 80:110, 52:67]
sub_cube2_rp5 = cube[14:16, 80:110, 52:67]
sub_cube2_rp6 = cube[14:16, 80:110, 53:68]
sub_cube2_rp8 = cube[14:16, 80:110, 54:69]
sub_cube2_rp10 = cube[14:16, 80:110, 55:70]
sub_cube2_rp12 = cube[14:16, 80:110, ]
sub_cube2_rn1 = cube[14:16, 80:110, 50:65]
sub_cube2_rn2 = cube[14:16, 80:110, 49:64]
sub_cube2_rn3 = cube[14:16, 80:110, 49:64]
sub_cube2_rn4 = cube[14:16, 80:110, 48:63]
sub_cube2_rn5 = cube[14:16, 80:110, 48:63]
sub_cube2_rn6 = cube[14:16, 80:110, 47:62]
sub_cube2_rn8 = cube[14:16, 80:110, 46:61]
sub_cube2_rn10 = cube[14:16, 80:110, 45:60]
sub_cube2_rn12 = cube[14:16, 80:110, ]

sub_cube3 = cube[16:18, 110:140, 50:65]
sub_cube3_rp1 = cube[16:18, 110:140, 51:66]
sub_cube3_rp2 = cube[16:18, 110:140, 52:67]
sub_cube3_rp3 = cube[16:18, 110:140, 53:68]
sub_cube3_rp4 = cube[16:18, 110:140, 54:69]
sub_cube3_rp5 = cube[16:18, 110:140, 55:70]
sub_cube3_rp6 = cube[16:18, 110:140, 56:71]
sub_cube3_rp8 = cube[16:18, 110:140, 58:73]
sub_cube3_rp10 = cube[16:18, 110:140, 60:75]
sub_cube3_rp12 = cube[16:18, 110:140, ]
sub_cube3_rn1 = cube[16:18, 110:140, 49:64]
sub_cube3_rn2 = cube[16:18, 110:140, 48:63]
sub_cube3_rn3 = cube[16:18, 110:140, 47:62]
sub_cube3_rn4 = cube[16:18, 110:140, 46:61]
sub_cube3_rn5 = cube[16:18, 110:140, 45:60]
sub_cube3_rn6 = cube[16:18, 110:140, 44:59]
sub_cube3_rn8 = cube[16:18, 110:140, 42:57]
sub_cube3_rn10 = cube[16:18, 110:140, 40:55]
sub_cube3_rn12 = cube[16:18, 110:140, ]

sub_cube4 = cube[18:20, 140:170, 50:65]
sub_cube4_rp1 = cube[18:20, 140:170, 52:67]
sub_cube4_rp2 = cube[18:20, 140:170, 53:68]
sub_cube4_rp3 = cube[18:20, 140:170, 55:70]
sub_cube4_rp4 = cube[18:20, 140:170, 56:71]
sub_cube4_rp5 = cube[18:20, 140:170, 58:73]
sub_cube4_rp6 = cube[18:20, 140:170, 59:74]
sub_cube4_rp8 = cube[18:20, 140:170, 63:78]
sub_cube4_rp10 = cube[18:20, 140:170, 66:81]
sub_cube4_rp12 = cube[18:20, 140:170, ]
sub_cube4_rn1 = cube[18:20, 140:170, 48:63]
sub_cube4_rn2 = cube[18:20, 140:170, 47:62]
sub_cube4_rn3 = cube[18:20, 140:170, 45:60]
sub_cube4_rn4 = cube[18:20, 140:170, 44:59]
sub_cube4_rn5 = cube[18:20, 140:170, 42:57]
sub_cube4_rn6 = cube[18:20, 140:170, 41:56]
sub_cube4_rn8 = cube[18:20, 140:170, 37:52]
sub_cube4_rn10 = cube[18:20, 140:170, 34:49]
sub_cube4_rn12 = cube[18:20, 140:170, ]

for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1 = np.average(sub_cube1)
a1_rp1 = np.average(sub_cube1_rp1)
a1_rp2 = np.average(sub_cube1_rp2)
a1_rp3 = np.average(sub_cube1_rp3)
a1_rp4 = np.average(sub_cube1_rp4)
a1_rp5 = np.average(sub_cube1_rp5)
a1_rp10 = np.average(sub_cube1_rp10)
a1_rp15 = np.average(sub_cube1_rp15)
a1_rp20 = np.average(sub_cube1_rp20)
a1_rn1 = np.average(sub_cube1_rn1)
a1_rn2 = np.average(sub_cube1_rn2)
a1_rn3 = np.average(sub_cube1_rn3)
a1_rn4 = np.average(sub_cube1_rn4)
a1_rn5 = np.average(sub_cube1_rn5)
a1_rn10 = np.average(sub_cube1_rn10)
a1_rn15 = np.average(sub_cube1_rn15)
a1_rn20 = np.average(sub_cube1_rn20)

a2 = np.average(sub_cube2)
a2_rp1 = np.average(sub_cube2_rp1)
a2_rp2 = np.average(sub_cube2_rp2)
a2_rp3 = np.average(sub_cube2_rp3)
a2_rp4 = np.average(sub_cube2_rp4)
a2_rp5 = np.average(sub_cube2_rp5)
a2_rp10 = np.average(sub_cube2_rp10)
a2_rp15 = np.average(sub_cube2_rp15)
a2_rp20 = np.average(sub_cube2_rp20)
a2_rn1 = np.average(sub_cube2_rn1)
a2_rn2 = np.average(sub_cube2_rn2)
a2_rn3 = np.average(sub_cube2_rn3)
a2_rn4 = np.average(sub_cube2_rn4)
a2_rn5 = np.average(sub_cube2_rn5)
a2_rn10 = np.average(sub_cube2_rn10)
a2_rn15 = np.average(sub_cube2_rn15)
a2_rn20 = np.average(sub_cube2_rn20)

a3 = np.average(sub_cube3)
a3_rp1 = np.average(sub_cube3_rp1)
a3_rp2 = np.average(sub_cube3_rp2)
a3_rp3 = np.average(sub_cube3_rp3)
a3_rp4 = np.average(sub_cube3_rp4)
a3_rp5 = np.average(sub_cube3_rp5)
a3_rp10 = np.average(sub_cube3_rp10)
a3_rp15 = np.average(sub_cube3_rp15)
a3_rp20 = np.average(sub_cube3_rp20)
a3_rn1 = np.average(sub_cube3_rn1)
a3_rn2 = np.average(sub_cube3_rn2)
a3_rn3 = np.average(sub_cube3_rn3)
a3_rn4 = np.average(sub_cube3_rn4)
a3_rn5 = np.average(sub_cube3_rn5)
a3_rn10 = np.average(sub_cube3_rn10)
a3_rn15 = np.average(sub_cube3_rn15)
a3_rn20 = np.average(sub_cube3_rn20)

a4 = np.average(sub_cube4)
a4_rp1 = np.average(sub_cube4_rp1)
a4_rp2 = np.average(sub_cube4_rp2)
a4_rp3 = np.average(sub_cube4_rp3)
a4_rp4 = np.average(sub_cube4_rp4)
a4_rp5 = np.average(sub_cube4_rp5)
a4_rp10 = np.average(sub_cube4_rp10)
a4_rp15 = np.average(sub_cube4_rp15)
a4_rp20 = np.average(sub_cube4_rp20)
a4_rn1 = np.average(sub_cube4_rn1)
a4_rn2 = np.average(sub_cube4_rn2)
a4_rn3 = np.average(sub_cube4_rn3)
a4_rn4 = np.average(sub_cube4_rn4)
a4_rn5 = np.average(sub_cube4_rn5)
a4_rn10 = np.average(sub_cube4_rn10)
a4_rn15 = np.average(sub_cube4_rn15)
a4_rn20 = np.average(sub_cube4_rn20)


sum = a1 + a2 + a3 + a4
sum_rp1 = a1_rp1 + a2_rp1 + a3_rp1 + a4_rp1
sum_rp2 = a1_rp2 + a2_rp2 + a3_rp2 + a4_rp2
sum_rp3 = a1_rp3 + a2_rp3 + a3_rp3 + a4_rp3
sum_rp4 = a1_rp4 + a2_rp4 + a3_rp4 + a4_rp4
sum_rp5 = a1_rp5 + a2_rp5 + a3_rp5 + a4_rp5
sum_rp10 = a1_rp10 + a2_rp10 + a3_rp10 + a4_rp10
sum_rp15 = a1_rp15 + a2_rp15 + a3_rp15 + a4_rp15
sum_rp20 = a1_rp20 + a2_rp20 + a3_rp20 + a4_rp20
sum_rn1 = a1_rn1 + a2_rn1 + a3_rn1 + a4_rn1
sum_rn2 = a1_rn2 + a2_rn2 + a3_rn2 + a4_rn2
sum_rn3 = a1_rn3 + a2_rn3 + a3_rn3 + a4_rn3
sum_rn4 = a1_rn4 + a2_rn4 + a3_rn4 + a4_rn4
sum_rn5 = a1_rn5 + a2_rn5 + a3_rn5 + a4_rn5
sum_rn10 = a1_rn10 + a2_rn10 + a3_rn10 + a4_rn10
sum_rn15 = a1_rn15 + a2_rn15 + a3_rn15 + a4_rn15
sum_rn20 = a1_rn20 + a2_rn20 + a3_rn20 + a4_rn20

print("Sum = ", sum)
print("Sum_rp1 = ", sum_rp1)
print("Sum_rn1 = ", sum_rn1)
print("Sum_rp2 = ", sum_rp2)
print("Sum_rn2 = ", sum_rn2)
print("Sum_rp3 = ", sum_rp3)
print("Sum_rn3 = ", sum_rn3)
print("Sum_rp4 = ", sum_rp4)
print("Sum_rn4 = ", sum_rn4)
print("Sum_rp5 = ", sum_rp5)
print("Sum_rn5 = ", sum_rn5)
print("Sum_rp10 = ", sum_rp10)
print("Sum_rn10 = ", sum_rn10)
print("Sum_rp15 = ", sum_rp15)
print("Sum_rn15 = ", sum_rn15)
print("Sum_rp20 = ", sum_rp20)
print("Sum_rn20 = ", sum_rn20)

diff_sigma = (sum * 5.7) / 0.00046608012
diff_sigma_rp1 = (sum_rp1 * 5.7) / 0.00046608012
diff_sigma_rn1 = (sum_rn1 * 5.7) / 0.00046608012
diff_sigma_rp2 = (sum_rp2 * 5.7) / 0.00046608012
diff_sigma_rn2 = (sum_rn2 * 5.7) / 0.00046608012
diff_sigma_rp3 = (sum_rp3 * 5.7) / 0.00046608012
diff_sigma_rn3 = (sum_rn3 * 5.7) / 0.00046608012
diff_sigma_rp4 = (sum_rp4 * 5.7) / 0.00046608012
diff_sigma_rn4 = (sum_rn4 * 5.7) / 0.00046608012
diff_sigma_rp5 = (sum_rp5 * 5.7) / 0.00046608012
diff_sigma_rn5 = (sum_rn5 * 5.7) / 0.00046608012
diff_sigma_rp10 = (sum_rp10 * 5.7) / 0.00046608012
diff_sigma_rn10 = (sum_rn10 * 5.7) / 0.00046608012
diff_sigma_rp15 = (sum_rp15 * 5.7) / 0.00046608012
diff_sigma_rn15 = (sum_rn15 * 5.7) / 0.00046608012
diff_sigma_rp20 = (sum_rp20 * 5.7) / 0.00046608012
diff_sigma_rn20 = (sum_rn20 * 5.7) / 0.00046608012

print("Sigma p0 = ", diff_sigma)
print("Sigma rp1 = ", diff_sigma_rp1)
print("Sigma rn1 = ", diff_sigma_rn1)
print("Sigma rp2 = ", diff_sigma_rp2)
print("Sigma rn2 = ", diff_sigma_rn2)
print("Sigma rp3 = ", diff_sigma_rp3)
print("Sigma rn3 = ", diff_sigma_rn3)
print("Sigma rp4 = ", diff_sigma_rp4)
print("Sigma rn4 = ", diff_sigma_rn4)
print("Sigma rp5 = ", diff_sigma_rp5)
print("Sigma rn5 = ", diff_sigma_rn5)
print("Sigma rp10 = ", diff_sigma_rp10)
print("Sigma rn10 = ", diff_sigma_rn10)
print("Sigma rp15 = ", diff_sigma_rp15)
print("Sigma rn15 = ", diff_sigma_rn15)
print("Sigma rp20 = ", diff_sigma_rp20)
print("Sigma rn20 = ", diff_sigma_rn20)

P_norm = scipy.stats.norm.sf(abs(5.7))

P_stat = scipy.stats.norm.sf(abs(diff_sigma))
P_stat_rp1 = scipy.stats.norm.sf(abs(diff_sigma_rp1))
P_stat_rn1 = scipy.stats.norm.sf(abs(diff_sigma_rn1))
P_stat_rp2 = scipy.stats.norm.sf(abs(diff_sigma_rp2))
P_stat_rn2 = scipy.stats.norm.sf(abs(diff_sigma_rn2))
P_stat_rp3 = scipy.stats.norm.sf(abs(diff_sigma_rp3))
P_stat_rn3 = scipy.stats.norm.sf(abs(diff_sigma_rn3))
P_stat_rp4 = scipy.stats.norm.sf(abs(diff_sigma_rp4))
P_stat_rn4 = scipy.stats.norm.sf(abs(diff_sigma_rn4))
P_stat_rp5 = scipy.stats.norm.sf(abs(diff_sigma_rp5))
P_stat_rn5 = scipy.stats.norm.sf(abs(diff_sigma_rn5))
P_stat_rp10 = scipy.stats.norm.sf(abs(diff_sigma_rp10))
P_stat_rn10 = scipy.stats.norm.sf(abs(diff_sigma_rn10))
P_stat_rp15 = scipy.stats.norm.sf(abs(diff_sigma_rp15))
P_stat_rn15 = scipy.stats.norm.sf(abs(diff_sigma_rn15))
P_stat_rp20 = scipy.stats.norm.sf(abs(diff_sigma_rp20))
P_stat_rn20 = scipy.stats.norm.sf(abs(diff_sigma_rn20))

P_corr = P_stat / P_norm
P_corr_rp1 = P_stat_rp1 / (5 * P_norm)
P_corr_rn1 = P_stat_rn1 / (5 * P_norm)
P_corr_rp2 = P_stat_rp2 / (9 * P_norm)
P_corr_rn2 = P_stat_rn2 / (9 * P_norm)
P_corr_rp3 = P_stat_rp3 / (13 * P_norm)
P_corr_rn3 = P_stat_rn3 / (13 * P_norm)
P_corr_rp4 = P_stat_rp4 / (13 * P_norm)
P_corr_rn4 = P_stat_rn4 / (13 * P_norm)
P_corr_rp5 = P_stat_rp5 / (13 * P_norm)
P_corr_rn5 = P_stat_rn5 / (13 * P_norm)
P_corr_rp10 = P_stat_rp10 / (13 * P_norm)
P_corr_rn10 = P_stat_rn10 / (13 * P_norm)
P_corr_rp15 = P_stat_rp15 / (13 * P_norm)
P_corr_rn15 = P_stat_rn15 / (13 * P_norm)
P_corr_rp20 = P_stat_rp20 / (13 * P_norm)
P_corr_rn20 = P_stat_rn20 / (13 * P_norm)

print(P_corr)
print("Pos1 =",P_corr_rp1)
print("Neg1 =",P_corr_rn1)
print("Pos2 =",P_corr_rp2)
print("Neg2 =",P_corr_rn2)
print("Pos3 =",P_corr_rp3)
print("Neg3 =",P_corr_rn3)
print("Pos4 =",P_corr_rp4)
print("Neg4 =",P_corr_rn4)
print("Pos5 =",P_corr_rp5)
print("Neg5 =",P_corr_rn5)
print("Pos10 =",P_corr_rp10)
print("Neg10 =",P_corr_rn10)
print("Pos15 =",P_corr_rp15)
print("Neg15 =",P_corr_rn15)
print("Pos20 =",P_corr_rp20)
print("Neg20 =",P_corr_rn20)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1 = cube[12:14, 50:80, 50:65]
sub_cube1_rp2 = cube[12:14, 50:80, 50:65]
sub_cube1_rp4 = cube[12:14, 50:80, 50:65]
sub_cube1_rp6 = cube[12:14, 50:80, 50:65]
sub_cube1_rp8 = cube[12:14, 50:80, 50:65]
sub_cube1_rp10 = cube[12:14, 50:80, 50:65]
sub_cube1_rp12 = cube[12:14, 50:80, 50:65]
sub_cube1_rp14 = cube[12:14, 50:80, 50:65]
sub_cube1_rp16 = cube[12:14, 50:80, 50:65]
sub_cube1_rp18 = cube[12:14, 50:80, 50:65]
sub_cube1_rp20 = cube[12:14, 50:80, 50:65]
sub_cube1_rp22 = cube[12:14, 50:80, 50:65]
sub_cube1_rp24 = cube[12:14, 50:80, 50:65]
sub_cube1_rp26 = cube[12:14, 50:80, 50:65]
sub_cube1_rn2 = cube[12:14, 50:80, 50:65]
sub_cube1_rn4 = cube[12:14, 50:80, 50:65]
sub_cube1_rn6 = cube[12:14, 50:80, 50:65]
sub_cube1_rn8 = cube[12:14, 50:80, 50:65]
sub_cube1_rn10 = cube[12:14, 50:80, 50:65]
sub_cube1_rn12 = cube[12:14, 50:80, 50:65]
sub_cube1_rn14 = cube[12:14, 50:80, 50:65]
sub_cube1_rn16 = cube[12:14, 50:80, 50:65]
sub_cube1_rn18 = cube[12:14, 50:80, 50:65]
sub_cube1_rn20 = cube[12:14, 50:80, 50:65]
sub_cube1_rn22 = cube[12:14, 50:80, 50:65]
sub_cube1_rn24 = cube[12:14, 50:80, 50:65]
sub_cube1_rn26 = cube[12:14, 50:80, 50:65]

sub_cube2 = cube[14:16, 80:110, 50:65]
sub_cube2_rp2 = cube[14:16, 80:110, 50:65]
sub_cube2_rp4 = cube[14:16, 80:110, 51:66]
sub_cube2_rp6 = cube[14:16, 80:110, 52:67]
sub_cube2_rp8 = cube[14:16, 80:110, 52:67]
sub_cube2_rp10 = cube[14:16, 80:110, 53:68]
sub_cube2_rp12 = cube[14:16, 80:110, 53:68]
sub_cube2_rp14 = cube[14:16, 80:110, 54:69]
sub_cube2_rp16 = cube[14:16, 80:110, 54:69]
sub_cube2_rp18 = cube[14:16, 80:110, 55:70]
sub_cube2_rp20 = cube[14:16, 80:110, 56:71]
sub_cube2_rp22 = cube[14:16, 80:110, 56:71]
sub_cube2_rp24 = cube[14:16, 80:110, 57:72]
sub_cube2_rp26 = cube[14:16, 80:110, 57:72]
sub_cube2_rn2 = cube[14:16, 80:110, 50:65]
sub_cube2_rn4 = cube[14:16, 80:110, 49:64]
sub_cube2_rn6 = cube[14:16, 80:110, 48:63]
sub_cube2_rn8 = cube[14:16, 80:110, 48:63]
sub_cube2_rn10 = cube[14:16, 80:110, 47:62]
sub_cube2_rn12 = cube[14:16, 80:110, 47:62]
sub_cube2_rn14 = cube[14:16, 80:110, 46:61]
sub_cube2_rn16 = cube[14:16, 80:110, 46:61]
sub_cube2_rn18 = cube[14:16, 80:110, 45:60]
sub_cube2_rn20 = cube[14:16, 80:110, 44:59]
sub_cube2_rn22 = cube[14:16, 80:110, 44:59]
sub_cube2_rn24 = cube[14:16, 80:110, 43:58]
sub_cube2_rn26 = cube[14:16, 80:110, 43:58]

sub_cube3 = cube[16:18, 110:140, 50:65]
sub_cube3_rp2 = cube[16:18, 110:140, 51:66]
sub_cube3_rp4 = cube[16:18, 110:140, 52:67]
sub_cube3_rp6 = cube[16:18, 110:140, 53:68]
sub_cube3_rp8 = cube[16:18, 110:140, 54:69]
sub_cube3_rp10 = cube[16:18, 110:140, 55:70]
sub_cube3_rp12 = cube[16:18, 110:140, 56:71]
sub_cube3_rp14 = cube[16:18, 110:140, 58:73]
sub_cube3_rp16 = cube[16:18, 110:140, 59:74]
sub_cube3_rp18 = cube[16:18, 110:140, 60:75]
sub_cube3_rp20 = cube[16:18, 110:140, 61:76]
sub_cube3_rp22 = cube[16:18, 110:140, 62:77]
sub_cube3_rp24 = cube[16:18, 110:140, 64:79]
sub_cube3_rp26 = cube[16:18, 110:140, 65:80]
sub_cube3_rn2 = cube[16:18, 110:140, 49:64]
sub_cube3_rn4 = cube[16:18, 110:140, 48:63]
sub_cube3_rn6 = cube[16:18, 110:140, 47:62]
sub_cube3_rn8 = cube[16:18, 110:140, 46:61]
sub_cube3_rn10 = cube[16:18, 110:140, 45:60]
sub_cube3_rn12 = cube[16:18, 110:140, 44:59]
sub_cube3_rn14 = cube[16:18, 110:140, 42:57]
sub_cube3_rn16 = cube[16:18, 110:140, 41:56]
sub_cube3_rn18 = cube[16:18, 110:140, 40:55]
sub_cube3_rn20 = cube[16:18, 110:140, 39:54]
sub_cube3_rn22 = cube[16:18, 110:140, 38:53]
sub_cube3_rn24 = cube[16:18, 110:140, 36:51]
sub_cube3_rn26 = cube[16:18, 110:140, 35:50]

sub_cube4 = cube[18:20, 140:170, 50:65]
sub_cube4_rp2 = cube[18:20, 140:170, 52:67]
sub_cube4_rp4 = cube[18:20, 140:170, 53:68]
sub_cube4_rp6 = cube[18:20, 140:170, 55:70]
sub_cube4_rp8 = cube[18:20, 140:170, 56:71]
sub_cube4_rp10 = cube[18:20, 140:170, 58:73]
sub_cube4_rp12 = cube[18:20, 140:170, 60:75]
sub_cube4_rp14 = cube[18:20, 140:170, 61:76]
sub_cube4_rp16 = cube[18:20, 140:170, 63:78]
sub_cube4_rp18 = cube[18:20, 140:170, 65:80]
sub_cube4_rp20 = cube[18:20, 140:170, 67:82]
sub_cube4_rp22 = cube[18:20, 140:170, 69:84]
sub_cube4_rp24 = cube[18:20, 140:170, 70:85]
sub_cube4_rp26 = cube[18:20, 140:170, 72:87]
sub_cube4_rn2 = cube[18:20, 140:170, 48:63]
sub_cube4_rn4 = cube[18:20, 140:170, 47:62]
sub_cube4_rn6 = cube[18:20, 140:170, 45:60]
sub_cube4_rn8 = cube[18:20, 140:170, 44:59]
sub_cube4_rn10 = cube[18:20, 140:170, 42:57]
sub_cube4_rn12 = cube[18:20, 140:170, 40:55]
sub_cube4_rn14 = cube[18:20, 140:170, 39:54]
sub_cube4_rn16 = cube[18:20, 140:170, 37:52]
sub_cube4_rn18 = cube[18:20, 140:170, 35:50]
sub_cube4_rn20 = cube[18:20, 140:170, 33:48]
sub_cube4_rn22 = cube[18:20, 140:170, 31:46]
sub_cube4_rn24 = cube[18:20, 140:170, 30:45]
sub_cube4_rn26 = cube[18:20, 140:170, 28:43]


for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1 = np.average(sub_cube1)
a1_rp2 = np.average(sub_cube1_rp2)
a1_rp4 = np.average(sub_cube1_rp4)
a1_rp6 = np.average(sub_cube1_rp6)
a1_rp8 = np.average(sub_cube1_rp8)
a1_rp10 = np.average(sub_cube1_rp10)
a1_rp12 = np.average(sub_cube1_rp12)
a1_rp14 = np.average(sub_cube1_rp14)
a1_rp16 = np.average(sub_cube1_rp16)
a1_rp18 = np.average(sub_cube1_rp18)
a1_rp20 = np.average(sub_cube1_rp20)
a1_rp22 = np.average(sub_cube1_rp22)
a1_rp24 = np.average(sub_cube1_rp24)
a1_rp26 = np.average(sub_cube1_rp26)
a1_rn2 = np.average(sub_cube1_rn2)
a1_rn4 = np.average(sub_cube1_rn4)
a1_rn6 = np.average(sub_cube1_rn6)
a1_rn8 = np.average(sub_cube1_rn8)
a1_rn10 = np.average(sub_cube1_rn10)
a1_rn12 = np.average(sub_cube1_rn12)
a1_rn14 = np.average(sub_cube1_rn14)
a1_rn16 = np.average(sub_cube1_rn16)
a1_rn18 = np.average(sub_cube1_rn18)
a1_rn20 = np.average(sub_cube1_rn20)
a1_rn22 = np.average(sub_cube1_rn22)
a1_rn24 = np.average(sub_cube1_rn24)
a1_rn26 = np.average(sub_cube1_rn26)

a2 = np.average(sub_cube2)
a2_rp2 = np.average(sub_cube2_rp2)
a2_rp4 = np.average(sub_cube2_rp4)
a2_rp6 = np.average(sub_cube2_rp6)
a2_rp8 = np.average(sub_cube2_rp8)
a2_rp10 = np.average(sub_cube2_rp10)
a2_rp12 = np.average(sub_cube2_rp12)
a2_rp14 = np.average(sub_cube2_rp14)
a2_rp16 = np.average(sub_cube2_rp16)
a2_rp18 = np.average(sub_cube2_rp18)
a2_rp20 = np.average(sub_cube2_rp20)
a2_rp22 = np.average(sub_cube2_rp22)
a2_rp24 = np.average(sub_cube2_rp24)
a2_rp26 = np.average(sub_cube2_rp26)
a2_rn2 = np.average(sub_cube2_rn2)
a2_rn4 = np.average(sub_cube2_rn4)
a2_rn6 = np.average(sub_cube2_rn6)
a2_rn8 = np.average(sub_cube2_rn8)
a2_rn10 = np.average(sub_cube2_rn10)
a2_rn12 = np.average(sub_cube2_rn12)
a2_rn14 = np.average(sub_cube2_rn14)
a2_rn16 = np.average(sub_cube2_rn16)
a2_rn18 = np.average(sub_cube2_rn18)
a2_rn20 = np.average(sub_cube2_rn20)
a2_rn22 = np.average(sub_cube2_rn22)
a2_rn24 = np.average(sub_cube2_rn24)
a2_rn26 = np.average(sub_cube2_rn26)

a3 = np.average(sub_cube3)
a3_rp2 = np.average(sub_cube3_rp2)
a3_rp4 = np.average(sub_cube3_rp4)
a3_rp6 = np.average(sub_cube3_rp6)
a3_rp8 = np.average(sub_cube3_rp8)
a3_rp10 = np.average(sub_cube3_rp10)
a3_rp12 = np.average(sub_cube3_rp12)
a3_rp14 = np.average(sub_cube3_rp14)
a3_rp16 = np.average(sub_cube3_rp16)
a3_rp18 = np.average(sub_cube3_rp18)
a3_rp20 = np.average(sub_cube3_rp20)
a3_rp22 = np.average(sub_cube3_rp22)
a3_rp24 = np.average(sub_cube3_rp24)
a3_rp26 = np.average(sub_cube3_rp26)
a3_rn2 = np.average(sub_cube3_rn2)
a3_rn4 = np.average(sub_cube3_rn4)
a3_rn6 = np.average(sub_cube3_rn6)
a3_rn8 = np.average(sub_cube3_rn8)
a3_rn10 = np.average(sub_cube3_rn10)
a3_rn12 = np.average(sub_cube3_rn12)
a3_rn14 = np.average(sub_cube3_rn14)
a3_rn16 = np.average(sub_cube3_rn16)
a3_rn18 = np.average(sub_cube3_rn18)
a3_rn20 = np.average(sub_cube3_rn20)
a3_rn22 = np.average(sub_cube3_rn22)
a3_rn24 = np.average(sub_cube3_rn24)
a3_rn26 = np.average(sub_cube3_rn26)

a4 = np.average(sub_cube4)
a4_rp2 = np.average(sub_cube4_rp2)
a4_rp4 = np.average(sub_cube4_rp4)
a4_rp6 = np.average(sub_cube4_rp6)
a4_rp8 = np.average(sub_cube4_rp8)
a4_rp10 = np.average(sub_cube4_rp10)
a4_rp12 = np.average(sub_cube4_rp12)
a4_rp14 = np.average(sub_cube4_rp14)
a4_rp16 = np.average(sub_cube4_rp16)
a4_rp18 = np.average(sub_cube4_rp18)
a4_rp20 = np.average(sub_cube4_rp20)
a4_rp22 = np.average(sub_cube4_rp22)
a4_rp24 = np.average(sub_cube4_rp24)
a4_rp26 = np.average(sub_cube4_rp26)
a4_rn2 = np.average(sub_cube4_rn2)
a4_rn4 = np.average(sub_cube4_rn4)
a4_rn6 = np.average(sub_cube4_rn6)
a4_rn8 = np.average(sub_cube4_rn8)
a4_rn10 = np.average(sub_cube4_rn10)
a4_rn12 = np.average(sub_cube4_rn12)
a4_rn14 = np.average(sub_cube4_rn14)
a4_rn16 = np.average(sub_cube4_rn16)
a4_rn18 = np.average(sub_cube4_rn18)
a4_rn20 = np.average(sub_cube4_rn20)
a4_rn22 = np.average(sub_cube4_rn22)
a4_rn24 = np.average(sub_cube4_rn24)
a4_rn26 = np.average(sub_cube4_rn26)



sum = a1 + a2 + a3 + a4
sum_rp2 = a1_rp2 + a2_rp2 + a3_rp2 + a4_rp2
sum_rp4 = a1_rp4 + a2_rp4 + a3_rp4 + a4_rp4
sum_rp6 = a1_rp6 + a2_rp6 + a3_rp6 + a4_rp6
sum_rp8 = a1_rp8 + a2_rp8 + a3_rp8 + a4_rp8
sum_rp10 = a1_rp10 + a2_rp10 + a3_rp10 + a4_rp10
sum_rp12 = a1_rp12 + a2_rp12 + a3_rp12 + a4_rp12
sum_rp14 = a1_rp14 + a2_rp14 + a3_rp14 + a4_rp14
sum_rp16 = a1_rp16 + a2_rp16 + a3_rp16 + a4_rp16
sum_rp18 = a1_rp18 + a2_rp18 + a3_rp18 + a4_rp18
sum_rp20 = a1_rp20 + a2_rp20 + a3_rp20 + a4_rp20
sum_rp22 = a1_rp22 + a2_rp22 + a3_rp22 + a4_rp22
sum_rp24 = a1_rp24 + a2_rp24 + a3_rp24 + a4_rp24
sum_rp26 = a1_rp26 + a2_rp26 + a3_rp26 + a4_rp26
sum_rn2 = a1_rn2 + a2_rn2 + a3_rn2 + a4_rn2
sum_rn4 = a1_rn4 + a2_rn4 + a3_rn4 + a4_rn4
sum_rn6 = a1_rn6 + a2_rn6 + a3_rn6 + a4_rn6
sum_rn8 = a1_rn8 + a2_rn8 + a3_rn8 + a4_rn8
sum_rn10 = a1_rn10 + a2_rn10 + a3_rn10 + a4_rn10
sum_rn12 = a1_rn12 + a2_rn12 + a3_rn12 + a4_rn12
sum_rn14 = a1_rn14 + a2_rn14 + a3_rn14 + a4_rn14
sum_rn16 = a1_rn16 + a2_rn16 + a3_rn16 + a4_rn16
sum_rn18 = a1_rn18 + a2_rn18 + a3_rn18 + a4_rn18
sum_rn20 = a1_rn20 + a2_rn20 + a3_rn20 + a4_rn20
sum_rn22 = a1_rn22 + a2_rn22 + a3_rn22 + a4_rn22
sum_rn24 = a1_rn24 + a2_rn24 + a3_rn24 + a4_rn24
sum_rn26 = a1_rn26 + a2_rn26 + a3_rn26 + a4_rn26

print("Sum = ", sum)
print("Sum_rp2 = ", sum_rp2)
print("Sum_rn2 = ", sum_rn2)
print("Sum_rp4 = ", sum_rp4)
print("Sum_rn4 = ", sum_rn4)
print("Sum_rp6 = ", sum_rp6)
print("Sum_rn6 = ", sum_rn6)
print("Sum_rp8 = ", sum_rp8)
print("Sum_rn8 = ", sum_rn8)
print("Sum_rp10 = ", sum_rp10)
print("Sum_rn10 = ", sum_rn10)
print("Sum_rp12 = ", sum_rp12)
print("Sum_rn12 = ", sum_rn12)
print("Sum_rp14 = ", sum_rp14)
print("Sum_rn14 = ", sum_rn14)
print("Sum_rp16 = ", sum_rp16)
print("Sum_rn16 = ", sum_rn16)
print("Sum_rp18 = ", sum_rp18)
print("Sum_rn18 = ", sum_rn18)
print("Sum_rp20 = ", sum_rp20)
print("Sum_rn20 = ", sum_rn20)
print("Sum_rp22 = ", sum_rp22)
print("Sum_rn22 = ", sum_rn22)
print("Sum_rp24 = ", sum_rp24)
print("Sum_rn24 = ", sum_rn24)
print("Sum_rp26 = ", sum_rp26)
print("Sum_rn26 = ", sum_rn26)

diff_sigma = (sum * 5.7) / 0.00046608012
diff_sigma_rp2 = (sum_rp2 * 5.7) / 0.00046608012
diff_sigma_rn2 = (sum_rn2 * 5.7) / 0.00046608012
diff_sigma_rp4 = (sum_rp4 * 5.7) / 0.00046608012
diff_sigma_rn4 = (sum_rn4 * 5.7) / 0.00046608012
diff_sigma_rp6 = (sum_rp6 * 5.7) / 0.00046608012
diff_sigma_rn6 = (sum_rn6 * 5.7) / 0.00046608012
diff_sigma_rp8 = (sum_rp8 * 5.7) / 0.00046608012
diff_sigma_rn8 = (sum_rn8 * 5.7) / 0.00046608012
diff_sigma_rp10 = (sum_rp10 * 5.7) / 0.00046608012
diff_sigma_rn10 = (sum_rn10 * 5.7) / 0.00046608012
diff_sigma_rp12 = (sum_rp12 * 5.7) / 0.00046608012
diff_sigma_rn12 = (sum_rn12 * 5.7) / 0.00046608012
diff_sigma_rp14 = (sum_rp14 * 5.7) / 0.00046608012
diff_sigma_rn14 = (sum_rn14 * 5.7) / 0.00046608012
diff_sigma_rp16 = (sum_rp16 * 5.7) / 0.00046608012
diff_sigma_rn16 = (sum_rn16 * 5.7) / 0.00046608012
diff_sigma_rp18 = (sum_rp18 * 5.7) / 0.00046608012
diff_sigma_rn18 = (sum_rn18 * 5.7) / 0.00046608012
diff_sigma_rp20 = (sum_rp20 * 5.7) / 0.00046608012
diff_sigma_rn20 = (sum_rn20 * 5.7) / 0.00046608012
diff_sigma_rp22 = (sum_rp22 * 5.7) / 0.00046608012
diff_sigma_rn22 = (sum_rn22 * 5.7) / 0.00046608012
diff_sigma_rp24 = (sum_rp24 * 5.7) / 0.00046608012
diff_sigma_rn24 = (sum_rn24 * 5.7) / 0.00046608012
diff_sigma_rp26 = (sum_rp26 * 5.7) / 0.00046608012
diff_sigma_rn26 = (sum_rn26 * 5.7) / 0.00046608012

print("Sigma p0 = ", diff_sigma)
print("Sigma rp2 = ", diff_sigma_rp2)
print("Sigma rn2 = ", diff_sigma_rn2)
print("Sigma rp4 = ", diff_sigma_rp4)
print("Sigma rn4 = ", diff_sigma_rn4)
print("Sigma rp6 = ", diff_sigma_rp6)
print("Sigma rn6 = ", diff_sigma_rn6)
print("Sigma rp8 = ", diff_sigma_rp8)
print("Sigma rn8 = ", diff_sigma_rn8)
print("Sigma rp10 = ", diff_sigma_rp10)
print("Sigma rn10 = ", diff_sigma_rn10)
print("Sigma rp12 = ", diff_sigma_rp12)
print("Sigma rn12 = ", diff_sigma_rn12)
print("Sigma rp14 = ", diff_sigma_rp14)
print("Sigma rn14 = ", diff_sigma_rn14)
print("Sigma rp16 = ", diff_sigma_rp16)
print("Sigma rn16 = ", diff_sigma_rn16)
print("Sigma rp18 = ", diff_sigma_rp18)
print("Sigma rn18 = ", diff_sigma_rn18)
print("Sigma rp20 = ", diff_sigma_rp20)
print("Sigma rn20 = ", diff_sigma_rn20)
print("Sigma rp22 = ", diff_sigma_rp22)
print("Sigma rn22 = ", diff_sigma_rn22)
print("Sigma rp24 = ", diff_sigma_rp24)
print("Sigma rn24 = ", diff_sigma_rn24)
print("Sigma rp26 = ", diff_sigma_rp26)
print("Sigma rn26 = ", diff_sigma_rn26)

P_norm = scipy.stats.norm.sf(abs(5.7))

P_stat = scipy.stats.norm.sf(abs(diff_sigma))
P_stat_rp2 = scipy.stats.norm.sf(abs(diff_sigma_rp2))
P_stat_rn2 = scipy.stats.norm.sf(abs(diff_sigma_rn2))
P_stat_rp4 = scipy.stats.norm.sf(abs(diff_sigma_rp4))
P_stat_rn4 = scipy.stats.norm.sf(abs(diff_sigma_rn4))
P_stat_rp6 = scipy.stats.norm.sf(abs(diff_sigma_rp6))
P_stat_rn6 = scipy.stats.norm.sf(abs(diff_sigma_rn6))
P_stat_rp8 = scipy.stats.norm.sf(abs(diff_sigma_rp8))
P_stat_rn8 = scipy.stats.norm.sf(abs(diff_sigma_rn8))
P_stat_rp10 = scipy.stats.norm.sf(abs(diff_sigma_rp10))
P_stat_rn10 = scipy.stats.norm.sf(abs(diff_sigma_rn10))
P_stat_rp12 = scipy.stats.norm.sf(abs(diff_sigma_rp12))
P_stat_rn12 = scipy.stats.norm.sf(abs(diff_sigma_rn12))
P_stat_rp14 = scipy.stats.norm.sf(abs(diff_sigma_rp14))
P_stat_rn14 = scipy.stats.norm.sf(abs(diff_sigma_rn14))
P_stat_rp16 = scipy.stats.norm.sf(abs(diff_sigma_rp16))
P_stat_rn16 = scipy.stats.norm.sf(abs(diff_sigma_rn16))
P_stat_rp18 = scipy.stats.norm.sf(abs(diff_sigma_rp18))
P_stat_rn18 = scipy.stats.norm.sf(abs(diff_sigma_rn18))
P_stat_rp20 = scipy.stats.norm.sf(abs(diff_sigma_rp20))
P_stat_rn20 = scipy.stats.norm.sf(abs(diff_sigma_rn20))
P_stat_rp22 = scipy.stats.norm.sf(abs(diff_sigma_rp22))
P_stat_rn22 = scipy.stats.norm.sf(abs(diff_sigma_rn22))
P_stat_rp24 = scipy.stats.norm.sf(abs(diff_sigma_rp24))
P_stat_rn24 = scipy.stats.norm.sf(abs(diff_sigma_rn24))
P_stat_rp26 = scipy.stats.norm.sf(abs(diff_sigma_rp26))
P_stat_rn26 = scipy.stats.norm.sf(abs(diff_sigma_rn26))

P_corr = P_stat / P_norm
P_corr_rp2 = P_stat_rp2 / (2.071 * P_norm)
P_corr_rn2 = P_stat_rn2 / (2.071 * P_norm)
P_corr_rp4 = P_stat_rp4 / (3.144 * P_norm)
P_corr_rn4 = P_stat_rn4 / (3.144 * P_norm)
P_corr_rp6 = P_stat_rp6 / (4.223 * P_norm)
P_corr_rn6 = P_stat_rn6 / (4.223 * P_norm)
P_corr_rp8 = P_stat_rp8 / (5.310 * P_norm)
P_corr_rn8 = P_stat_rn8 / (5.310 * P_norm)
P_corr_rp10 = P_stat_rp10 / (6.407 * P_norm)
P_corr_rn10 = P_stat_rn10 / (6.407 * P_norm)
P_corr_rp12 = P_stat_rp12 / (7.518 * P_norm)
P_corr_rn12 = P_stat_rn12 / (7.518 * P_norm)
P_corr_rp14 = P_stat_rp14 / (8.646 * P_norm)
P_corr_rn14 = P_stat_rn14 / (8.646 * P_norm)
P_corr_rp16 = P_stat_rp16 / (9.794 * P_norm)
P_corr_rn16 = P_stat_rn16 / (9.794 * P_norm)
P_corr_rp18 = P_stat_rp18 / (10.964 * P_norm)
P_corr_rn18 = P_stat_rn18 / (10.964 * P_norm)
P_corr_rp20 = P_stat_rp20 / (12.162 * P_norm)
P_corr_rn20 = P_stat_rn20 / (12.162 * P_norm)
P_corr_rp22 = P_stat_rp22 / (13.390 * P_norm)
P_corr_rn22 = P_stat_rn22 / (13.390 * P_norm)
P_corr_rp24 = P_stat_rp24 / (14.654 * P_norm)
P_corr_rn24 = P_stat_rn24 / (14.653 * P_norm)
P_corr_rp26 = P_stat_rp26 / (15.957 * P_norm)
P_corr_rn26 = P_stat_rn26 / (15.957 * P_norm)

print(P_corr)
print("Pos2 =",P_corr_rp2)
print("Neg2 =",P_corr_rn2)
print("Pos4 =",P_corr_rp4)
print("Neg4 =",P_corr_rn4)
print("Pos6 =",P_corr_rp6)
print("Neg6 =",P_corr_rn6)
print("Pos8 =",P_corr_rp8)
print("Neg8 =",P_corr_rn8)
print("Pos10 =",P_corr_rp10)
print("Neg10 =",P_corr_rn10)
print("Pos12 =",P_corr_rp12)
print("Neg12 =",P_corr_rn12)
print("Pos14 =",P_corr_rp14)
print("Neg14 =",P_corr_rn14)
print("Pos16 =",P_corr_rp16)
print("Neg16 =",P_corr_rn16)
print("Pos18 =",P_corr_rp18)
print("Neg18 =",P_corr_rn18)
print("Pos20 =",P_corr_rp20)
print("Neg20 =",P_corr_rn20)
print("Pos22 =",P_corr_rp22)
print("Neg22 =",P_corr_rn22)
print("Pos24 =",P_corr_rp24)
print("Neg24 =",P_corr_rn24)
print("Pos26 =",P_corr_rp26)
print("Neg26 =",P_corr_rn26)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1 = cube[12:14, 50:80, 50:65]
sub_cube1_rp2 = cube[12:14, 50:80, 50:65]
sub_cube1_rp4 = cube[12:14, 50:80, 50:65]
sub_cube1_rp6 = cube[12:14, 50:80, 50:65]
sub_cube1_rp8 = cube[12:14, 50:80, 50:65]
sub_cube1_rp10 = cube[12:14, 50:80, 50:65]
sub_cube1_rp12 = cube[12:14, 50:80, 50:65]
sub_cube1_rp14 = cube[12:14, 50:80, 50:65]
sub_cube1_rp16 = cube[12:14, 50:80, 50:65]
sub_cube1_rp18 = cube[12:14, 50:80, 50:65]
sub_cube1_rp20 = cube[12:14, 50:80, 50:65]
sub_cube1_rp22 = cube[12:14, 50:80, 50:65]
sub_cube1_rp24 = cube[12:14, 50:80, 50:65]
sub_cube1_rp26 = cube[12:14, 50:80, 50:65]
sub_cube1_rn2 = cube[12:14, 50:80, 50:65]
sub_cube1_rn4 = cube[12:14, 50:80, 50:65]
sub_cube1_rn6 = cube[12:14, 50:80, 50:65]
sub_cube1_rn8 = cube[12:14, 50:80, 50:65]
sub_cube1_rn10 = cube[12:14, 50:80, 50:65]
sub_cube1_rn12 = cube[12:14, 50:80, 50:65]
sub_cube1_rn14 = cube[12:14, 50:80, 50:65]
sub_cube1_rn16 = cube[12:14, 50:80, 50:65]
sub_cube1_rn18 = cube[12:14, 50:80, 50:65]
sub_cube1_rn20 = cube[12:14, 50:80, 50:65]
sub_cube1_rn22 = cube[12:14, 50:80, 50:65]
sub_cube1_rn24 = cube[12:14, 50:80, 50:65]
sub_cube1_rn26 = cube[12:14, 50:80, 50:65]

sub_cube2 = cube[14:16, 80:110, 50:65]
sub_cube2_rp2 = cube[14:16, 80:110, 50:65]
sub_cube2_rp4 = cube[14:16, 80:110, 51:66]
sub_cube2_rp6 = cube[14:16, 80:110, 52:67]
sub_cube2_rp8 = cube[14:16, 80:110, 52:67]
sub_cube2_rp10 = cube[14:16, 80:110, 53:68]
sub_cube2_rp12 = cube[14:16, 80:110, 53:68]
sub_cube2_rp14 = cube[14:16, 80:110, 54:69]
sub_cube2_rp16 = cube[14:16, 80:110, 54:69]
sub_cube2_rp18 = cube[14:16, 80:110, 55:70]
sub_cube2_rp20 = cube[14:16, 80:110, 56:71]
sub_cube2_rp22 = cube[14:16, 80:110, 56:71]
sub_cube2_rp24 = cube[14:16, 80:110, 57:72]
sub_cube2_rp26 = cube[14:16, 80:110, 57:72]
sub_cube2_rn2 = cube[14:16, 80:110, 50:65]
sub_cube2_rn4 = cube[14:16, 80:110, 49:64]
sub_cube2_rn6 = cube[14:16, 80:110, 48:63]
sub_cube2_rn8 = cube[14:16, 80:110, 48:63]
sub_cube2_rn10 = cube[14:16, 80:110, 47:62]
sub_cube2_rn12 = cube[14:16, 80:110, 47:62]
sub_cube2_rn14 = cube[14:16, 80:110, 46:61]
sub_cube2_rn16 = cube[14:16, 80:110, 46:61]
sub_cube2_rn18 = cube[14:16, 80:110, 45:60]
sub_cube2_rn20 = cube[14:16, 80:110, 44:59]
sub_cube2_rn22 = cube[14:16, 80:110, 44:59]
sub_cube2_rn24 = cube[14:16, 80:110, 43:58]
sub_cube2_rn26 = cube[14:16, 80:110, 43:58]

sub_cube3 = cube[16:18, 110:140, 50:65]
sub_cube3_rp2 = cube[16:18, 110:140, 51:66]
sub_cube3_rp4 = cube[16:18, 110:140, 52:67]
sub_cube3_rp6 = cube[16:18, 110:140, 53:68]
sub_cube3_rp8 = cube[16:18, 110:140, 54:69]
sub_cube3_rp10 = cube[16:18, 110:140, 55:70]
sub_cube3_rp12 = cube[16:18, 110:140, 56:71]
sub_cube3_rp14 = cube[16:18, 110:140, 58:73]
sub_cube3_rp16 = cube[16:18, 110:140, 59:74]
sub_cube3_rp18 = cube[16:18, 110:140, 60:75]
sub_cube3_rp20 = cube[16:18, 110:140, 61:76]
sub_cube3_rp22 = cube[16:18, 110:140, 62:77]
sub_cube3_rp24 = cube[16:18, 110:140, 64:79]
sub_cube3_rp26 = cube[16:18, 110:140, 65:80]
sub_cube3_rn2 = cube[16:18, 110:140, 49:64]
sub_cube3_rn4 = cube[16:18, 110:140, 48:63]
sub_cube3_rn6 = cube[16:18, 110:140, 47:62]
sub_cube3_rn8 = cube[16:18, 110:140, 46:61]
sub_cube3_rn10 = cube[16:18, 110:140, 45:60]
sub_cube3_rn12 = cube[16:18, 110:140, 44:59]
sub_cube3_rn14 = cube[16:18, 110:140, 42:57]
sub_cube3_rn16 = cube[16:18, 110:140, 41:56]
sub_cube3_rn18 = cube[16:18, 110:140, 40:55]
sub_cube3_rn20 = cube[16:18, 110:140, 39:54]
sub_cube3_rn22 = cube[16:18, 110:140, 38:53]
sub_cube3_rn24 = cube[16:18, 110:140, 36:51]
sub_cube3_rn26 = cube[16:18, 110:140, 35:50]

sub_cube4 = cube[18:20, 140:170, 50:65]
sub_cube4_rp2 = cube[18:20, 140:170, 52:67]
sub_cube4_rp4 = cube[18:20, 140:170, 53:68]
sub_cube4_rp6 = cube[18:20, 140:170, 55:70]
sub_cube4_rp8 = cube[18:20, 140:170, 56:71]
sub_cube4_rp10 = cube[18:20, 140:170, 58:73]
sub_cube4_rp12 = cube[18:20, 140:170, 60:75]
sub_cube4_rp14 = cube[18:20, 140:170, 61:76]
sub_cube4_rp16 = cube[18:20, 140:170, 63:78]
sub_cube4_rp18 = cube[18:20, 140:170, 65:80]
sub_cube4_rp20 = cube[18:20, 140:170, 67:82]
sub_cube4_rp22 = cube[18:20, 140:170, 69:84]
sub_cube4_rp24 = cube[18:20, 140:170, 70:85]
sub_cube4_rp26 = cube[18:20, 140:170, 72:87]
sub_cube4_rn2 = cube[18:20, 140:170, 48:63]
sub_cube4_rn4 = cube[18:20, 140:170, 47:62]
sub_cube4_rn6 = cube[18:20, 140:170, 45:60]
sub_cube4_rn8 = cube[18:20, 140:170, 44:59]
sub_cube4_rn10 = cube[18:20, 140:170, 42:57]
sub_cube4_rn12 = cube[18:20, 140:170, 40:55]
sub_cube4_rn14 = cube[18:20, 140:170, 39:54]
sub_cube4_rn16 = cube[18:20, 140:170, 37:52]
sub_cube4_rn18 = cube[18:20, 140:170, 35:50]
sub_cube4_rn20 = cube[18:20, 140:170, 33:48]
sub_cube4_rn22 = cube[18:20, 140:170, 31:46]
sub_cube4_rn24 = cube[18:20, 140:170, 30:45]
sub_cube4_rn26 = cube[18:20, 140:170, 28:43]


for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1 = np.average(sub_cube1)
a1_rp2 = np.average(sub_cube1_rp2)
a1_rp4 = np.average(sub_cube1_rp4)
a1_rp6 = np.average(sub_cube1_rp6)
a1_rp8 = np.average(sub_cube1_rp8)
a1_rp10 = np.average(sub_cube1_rp10)
a1_rp12 = np.average(sub_cube1_rp12)
a1_rp14 = np.average(sub_cube1_rp14)
a1_rp16 = np.average(sub_cube1_rp16)
a1_rp18 = np.average(sub_cube1_rp18)
a1_rp20 = np.average(sub_cube1_rp20)
a1_rp22 = np.average(sub_cube1_rp22)
a1_rp24 = np.average(sub_cube1_rp24)
a1_rp26 = np.average(sub_cube1_rp26)
a1_rn2 = np.average(sub_cube1_rn2)
a1_rn4 = np.average(sub_cube1_rn4)
a1_rn6 = np.average(sub_cube1_rn6)
a1_rn8 = np.average(sub_cube1_rn8)
a1_rn10 = np.average(sub_cube1_rn10)
a1_rn12 = np.average(sub_cube1_rn12)
a1_rn14 = np.average(sub_cube1_rn14)
a1_rn16 = np.average(sub_cube1_rn16)
a1_rn18 = np.average(sub_cube1_rn18)
a1_rn20 = np.average(sub_cube1_rn20)
a1_rn22 = np.average(sub_cube1_rn22)
a1_rn24 = np.average(sub_cube1_rn24)
a1_rn26 = np.average(sub_cube1_rn26)

a2 = np.average(sub_cube2)
a2_rp2 = np.average(sub_cube2_rp2)
a2_rp4 = np.average(sub_cube2_rp4)
a2_rp6 = np.average(sub_cube2_rp6)
a2_rp8 = np.average(sub_cube2_rp8)
a2_rp10 = np.average(sub_cube2_rp10)
a2_rp12 = np.average(sub_cube2_rp12)
a2_rp14 = np.average(sub_cube2_rp14)
a2_rp16 = np.average(sub_cube2_rp16)
a2_rp18 = np.average(sub_cube2_rp18)
a2_rp20 = np.average(sub_cube2_rp20)
a2_rp22 = np.average(sub_cube2_rp22)
a2_rp24 = np.average(sub_cube2_rp24)
a2_rp26 = np.average(sub_cube2_rp26)
a2_rn2 = np.average(sub_cube2_rn2)
a2_rn4 = np.average(sub_cube2_rn4)
a2_rn6 = np.average(sub_cube2_rn6)
a2_rn8 = np.average(sub_cube2_rn8)
a2_rn10 = np.average(sub_cube2_rn10)
a2_rn12 = np.average(sub_cube2_rn12)
a2_rn14 = np.average(sub_cube2_rn14)
a2_rn16 = np.average(sub_cube2_rn16)
a2_rn18 = np.average(sub_cube2_rn18)
a2_rn20 = np.average(sub_cube2_rn20)
a2_rn22 = np.average(sub_cube2_rn22)
a2_rn24 = np.average(sub_cube2_rn24)
a2_rn26 = np.average(sub_cube2_rn26)

a3 = np.average(sub_cube3)
a3_rp2 = np.average(sub_cube3_rp2)
a3_rp4 = np.average(sub_cube3_rp4)
a3_rp6 = np.average(sub_cube3_rp6)
a3_rp8 = np.average(sub_cube3_rp8)
a3_rp10 = np.average(sub_cube3_rp10)
a3_rp12 = np.average(sub_cube3_rp12)
a3_rp14 = np.average(sub_cube3_rp14)
a3_rp16 = np.average(sub_cube3_rp16)
a3_rp18 = np.average(sub_cube3_rp18)
a3_rp20 = np.average(sub_cube3_rp20)
a3_rp22 = np.average(sub_cube3_rp22)
a3_rp24 = np.average(sub_cube3_rp24)
a3_rp26 = np.average(sub_cube3_rp26)
a3_rn2 = np.average(sub_cube3_rn2)
a3_rn4 = np.average(sub_cube3_rn4)
a3_rn6 = np.average(sub_cube3_rn6)
a3_rn8 = np.average(sub_cube3_rn8)
a3_rn10 = np.average(sub_cube3_rn10)
a3_rn12 = np.average(sub_cube3_rn12)
a3_rn14 = np.average(sub_cube3_rn14)
a3_rn16 = np.average(sub_cube3_rn16)
a3_rn18 = np.average(sub_cube3_rn18)
a3_rn20 = np.average(sub_cube3_rn20)
a3_rn22 = np.average(sub_cube3_rn22)
a3_rn24 = np.average(sub_cube3_rn24)
a3_rn26 = np.average(sub_cube3_rn26)

a4 = np.average(sub_cube4)
a4_rp2 = np.average(sub_cube4_rp2)
a4_rp4 = np.average(sub_cube4_rp4)
a4_rp6 = np.average(sub_cube4_rp6)
a4_rp8 = np.average(sub_cube4_rp8)
a4_rp10 = np.average(sub_cube4_rp10)
a4_rp12 = np.average(sub_cube4_rp12)
a4_rp14 = np.average(sub_cube4_rp14)
a4_rp16 = np.average(sub_cube4_rp16)
a4_rp18 = np.average(sub_cube4_rp18)
a4_rp20 = np.average(sub_cube4_rp20)
a4_rp22 = np.average(sub_cube4_rp22)
a4_rp24 = np.average(sub_cube4_rp24)
a4_rp26 = np.average(sub_cube4_rp26)
a4_rn2 = np.average(sub_cube4_rn2)
a4_rn4 = np.average(sub_cube4_rn4)
a4_rn6 = np.average(sub_cube4_rn6)
a4_rn8 = np.average(sub_cube4_rn8)
a4_rn10 = np.average(sub_cube4_rn10)
a4_rn12 = np.average(sub_cube4_rn12)
a4_rn14 = np.average(sub_cube4_rn14)
a4_rn16 = np.average(sub_cube4_rn16)
a4_rn18 = np.average(sub_cube4_rn18)
a4_rn20 = np.average(sub_cube4_rn20)
a4_rn22 = np.average(sub_cube4_rn22)
a4_rn24 = np.average(sub_cube4_rn24)
a4_rn26 = np.average(sub_cube4_rn26)



sum = a1 + a2 + a3 + a4
sum_rp2 = a1_rp2 + a2_rp2 + a3_rp2 + a4_rp2
sum_rp4 = a1_rp4 + a2_rp4 + a3_rp4 + a4_rp4
sum_rp6 = a1_rp6 + a2_rp6 + a3_rp6 + a4_rp6
sum_rp8 = a1_rp8 + a2_rp8 + a3_rp8 + a4_rp8
sum_rp10 = a1_rp10 + a2_rp10 + a3_rp10 + a4_rp10
sum_rp12 = a1_rp12 + a2_rp12 + a3_rp12 + a4_rp12
sum_rp14 = a1_rp14 + a2_rp14 + a3_rp14 + a4_rp14
sum_rp16 = a1_rp16 + a2_rp16 + a3_rp16 + a4_rp16
sum_rp18 = a1_rp18 + a2_rp18 + a3_rp18 + a4_rp18
sum_rp20 = a1_rp20 + a2_rp20 + a3_rp20 + a4_rp20
sum_rp22 = a1_rp22 + a2_rp22 + a3_rp22 + a4_rp22
sum_rp24 = a1_rp24 + a2_rp24 + a3_rp24 + a4_rp24
sum_rp26 = a1_rp26 + a2_rp26 + a3_rp26 + a4_rp26
sum_rn2 = a1_rn2 + a2_rn2 + a3_rn2 + a4_rn2
sum_rn4 = a1_rn4 + a2_rn4 + a3_rn4 + a4_rn4
sum_rn6 = a1_rn6 + a2_rn6 + a3_rn6 + a4_rn6
sum_rn8 = a1_rn8 + a2_rn8 + a3_rn8 + a4_rn8
sum_rn10 = a1_rn10 + a2_rn10 + a3_rn10 + a4_rn10
sum_rn12 = a1_rn12 + a2_rn12 + a3_rn12 + a4_rn12
sum_rn14 = a1_rn14 + a2_rn14 + a3_rn14 + a4_rn14
sum_rn16 = a1_rn16 + a2_rn16 + a3_rn16 + a4_rn16
sum_rn18 = a1_rn18 + a2_rn18 + a3_rn18 + a4_rn18
sum_rn20 = a1_rn20 + a2_rn20 + a3_rn20 + a4_rn20
sum_rn22 = a1_rn22 + a2_rn22 + a3_rn22 + a4_rn22
sum_rn24 = a1_rn24 + a2_rn24 + a3_rn24 + a4_rn24
sum_rn26 = a1_rn26 + a2_rn26 + a3_rn26 + a4_rn26

print("Sum = ", sum)
print("Sum_rp2 = ", sum_rp2)
print("Sum_rn2 = ", sum_rn2)
print("Sum_rp4 = ", sum_rp4)
print("Sum_rn4 = ", sum_rn4)
print("Sum_rp6 = ", sum_rp6)
print("Sum_rn6 = ", sum_rn6)
print("Sum_rp8 = ", sum_rp8)
print("Sum_rn8 = ", sum_rn8)
print("Sum_rp10 = ", sum_rp10)
print("Sum_rn10 = ", sum_rn10)
print("Sum_rp12 = ", sum_rp12)
print("Sum_rn12 = ", sum_rn12)
print("Sum_rp14 = ", sum_rp14)
print("Sum_rn14 = ", sum_rn14)
print("Sum_rp16 = ", sum_rp16)
print("Sum_rn16 = ", sum_rn16)
print("Sum_rp18 = ", sum_rp18)
print("Sum_rn18 = ", sum_rn18)
print("Sum_rp20 = ", sum_rp20)
print("Sum_rn20 = ", sum_rn20)
print("Sum_rp22 = ", sum_rp22)
print("Sum_rn22 = ", sum_rn22)
print("Sum_rp24 = ", sum_rp24)
print("Sum_rn24 = ", sum_rn24)
print("Sum_rp26 = ", sum_rp26)
print("Sum_rn26 = ", sum_rn26)

diff_sigma = (sum * 5.7) / 0.00046608012
diff_sigma_rp2 = (sum_rp2 * 5.7) / 0.00046608012
diff_sigma_rn2 = (sum_rn2 * 5.7) / 0.00046608012
diff_sigma_rp4 = (sum_rp4 * 5.7) / 0.00046608012
diff_sigma_rn4 = (sum_rn4 * 5.7) / 0.00046608012
diff_sigma_rp6 = (sum_rp6 * 5.7) / 0.00046608012
diff_sigma_rn6 = (sum_rn6 * 5.7) / 0.00046608012
diff_sigma_rp8 = (sum_rp8 * 5.7) / 0.00046608012
diff_sigma_rn8 = (sum_rn8 * 5.7) / 0.00046608012
diff_sigma_rp10 = (sum_rp10 * 5.7) / 0.00046608012
diff_sigma_rn10 = (sum_rn10 * 5.7) / 0.00046608012
diff_sigma_rp12 = (sum_rp12 * 5.7) / 0.00046608012
diff_sigma_rn12 = (sum_rn12 * 5.7) / 0.00046608012
diff_sigma_rp14 = (sum_rp14 * 5.7) / 0.00046608012
diff_sigma_rn14 = (sum_rn14 * 5.7) / 0.00046608012
diff_sigma_rp16 = (sum_rp16 * 5.7) / 0.00046608012
diff_sigma_rn16 = (sum_rn16 * 5.7) / 0.00046608012
diff_sigma_rp18 = (sum_rp18 * 5.7) / 0.00046608012
diff_sigma_rn18 = (sum_rn18 * 5.7) / 0.00046608012
diff_sigma_rp20 = (sum_rp20 * 5.7) / 0.00046608012
diff_sigma_rn20 = (sum_rn20 * 5.7) / 0.00046608012
diff_sigma_rp22 = (sum_rp22 * 5.7) / 0.00046608012
diff_sigma_rn22 = (sum_rn22 * 5.7) / 0.00046608012
diff_sigma_rp24 = (sum_rp24 * 5.7) / 0.00046608012
diff_sigma_rn24 = (sum_rn24 * 5.7) / 0.00046608012
diff_sigma_rp26 = (sum_rp26 * 5.7) / 0.00046608012
diff_sigma_rn26 = (sum_rn26 * 5.7) / 0.00046608012

print("Sigma p0 = ", diff_sigma)
print("Sigma rp2 = ", diff_sigma_rp2)
print("Sigma rn2 = ", diff_sigma_rn2)
print("Sigma rp4 = ", diff_sigma_rp4)
print("Sigma rn4 = ", diff_sigma_rn4)
print("Sigma rp6 = ", diff_sigma_rp6)
print("Sigma rn6 = ", diff_sigma_rn6)
print("Sigma rp8 = ", diff_sigma_rp8)
print("Sigma rn8 = ", diff_sigma_rn8)
print("Sigma rp10 = ", diff_sigma_rp10)
print("Sigma rn10 = ", diff_sigma_rn10)
print("Sigma rp12 = ", diff_sigma_rp12)
print("Sigma rn12 = ", diff_sigma_rn12)
print("Sigma rp14 = ", diff_sigma_rp14)
print("Sigma rn14 = ", diff_sigma_rn14)
print("Sigma rp16 = ", diff_sigma_rp16)
print("Sigma rn16 = ", diff_sigma_rn16)
print("Sigma rp18 = ", diff_sigma_rp18)
print("Sigma rn18 = ", diff_sigma_rn18)
print("Sigma rp20 = ", diff_sigma_rp20)
print("Sigma rn20 = ", diff_sigma_rn20)
print("Sigma rp22 = ", diff_sigma_rp22)
print("Sigma rn22 = ", diff_sigma_rn22)
print("Sigma rp24 = ", diff_sigma_rp24)
print("Sigma rn24 = ", diff_sigma_rn24)
print("Sigma rp26 = ", diff_sigma_rp26)
print("Sigma rn26 = ", diff_sigma_rn26)

P_norm = scipy.stats.norm.sf(abs(5.7))

P_stat = scipy.stats.norm.sf(abs(diff_sigma))
P_stat_rp2 = scipy.stats.norm.sf(abs(diff_sigma_rp2))
P_stat_rn2 = scipy.stats.norm.sf(abs(diff_sigma_rn2))
P_stat_rp4 = scipy.stats.norm.sf(abs(diff_sigma_rp4))
P_stat_rn4 = scipy.stats.norm.sf(abs(diff_sigma_rn4))
P_stat_rp6 = scipy.stats.norm.sf(abs(diff_sigma_rp6))
P_stat_rn6 = scipy.stats.norm.sf(abs(diff_sigma_rn6))
P_stat_rp8 = scipy.stats.norm.sf(abs(diff_sigma_rp8))
P_stat_rn8 = scipy.stats.norm.sf(abs(diff_sigma_rn8))
P_stat_rp10 = scipy.stats.norm.sf(abs(diff_sigma_rp10))
P_stat_rn10 = scipy.stats.norm.sf(abs(diff_sigma_rn10))
P_stat_rp12 = scipy.stats.norm.sf(abs(diff_sigma_rp12))
P_stat_rn12 = scipy.stats.norm.sf(abs(diff_sigma_rn12))
P_stat_rp14 = scipy.stats.norm.sf(abs(diff_sigma_rp14))
P_stat_rn14 = scipy.stats.norm.sf(abs(diff_sigma_rn14))
P_stat_rp16 = scipy.stats.norm.sf(abs(diff_sigma_rp16))
P_stat_rn16 = scipy.stats.norm.sf(abs(diff_sigma_rn16))
P_stat_rp18 = scipy.stats.norm.sf(abs(diff_sigma_rp18))
P_stat_rn18 = scipy.stats.norm.sf(abs(diff_sigma_rn18))
P_stat_rp20 = scipy.stats.norm.sf(abs(diff_sigma_rp20))
P_stat_rn20 = scipy.stats.norm.sf(abs(diff_sigma_rn20))
P_stat_rp22 = scipy.stats.norm.sf(abs(diff_sigma_rp22))
P_stat_rn22 = scipy.stats.norm.sf(abs(diff_sigma_rn22))
P_stat_rp24 = scipy.stats.norm.sf(abs(diff_sigma_rp24))
P_stat_rn24 = scipy.stats.norm.sf(abs(diff_sigma_rn24))
P_stat_rp26 = scipy.stats.norm.sf(abs(diff_sigma_rp26))
P_stat_rn26 = scipy.stats.norm.sf(abs(diff_sigma_rn26))


P_corr = P_stat / (3.144 * P_norm)
P_corr_rp2 = P_stat_rp2 / (4.223* P_norm)
P_corr_rn2 = P_stat_rn2 / (2.071 * P_norm)
P_corr_rp4 = P_stat_rp4 / (5.310 * P_norm)
P_corr_rn4 = P_stat_rn4 / (1 * P_norm)
P_corr_rp6 = P_stat_rp6 / (6.407 * P_norm)
P_corr_rn6 = P_stat_rn6 / (2.071 * P_norm)
P_corr_rp8 = P_stat_rp8 / (7.518 * P_norm)
P_corr_rn8 = P_stat_rn8 / (3.144 * P_norm)
P_corr_rp10 = P_stat_rp10 / (8.646 * P_norm)
P_corr_rn10 = P_stat_rn10 / (4.223 * P_norm)
P_corr_rp12 = P_stat_rp12 / (9.794 * P_norm)
P_corr_rn12 = P_stat_rn12 / (5.310 * P_norm)
P_corr_rp14 = P_stat_rp14 / (10.964 * P_norm)
P_corr_rn14 = P_stat_rn14 / (6.407 * P_norm)
P_corr_rp16 = P_stat_rp16 / (12.162 * P_norm)
P_corr_rn16 = P_stat_rn16 / (7.518 * P_norm)
P_corr_rp18 = P_stat_rp18 / (13.390 * P_norm)
P_corr_rn18 = P_stat_rn18 / (8.646 * P_norm)
P_corr_rp20 = P_stat_rp20 / (14.654 * P_norm)
P_corr_rn20 = P_stat_rn20 / (9.794 * P_norm)
P_corr_rp22 = P_stat_rp22 / (15.957 * P_norm)
P_corr_rn22 = P_stat_rn22 / (10.964 * P_norm)
P_corr_rp24 = P_stat_rp24 / (15.957 * P_norm)
P_corr_rn24 = P_stat_rn24 / (12.162 * P_norm)
P_corr_rp26 = P_stat_rp26 / (15.957 * P_norm)
P_corr_rn26 = P_stat_rn26 / (13.390 * P_norm)



print(P_corr)
print("Pos2 =",P_corr_rp2)
print("Neg2 =",P_corr_rn2)
print("Pos4 =",P_corr_rp4)
print("Neg4 =",P_corr_rn4)
print("Pos6 =",P_corr_rp6)
print("Neg6 =",P_corr_rn6)
print("Pos8 =",P_corr_rp8)
print("Neg8 =",P_corr_rn8)
print("Pos10 =",P_corr_rp10)
print("Neg10 =",P_corr_rn10)
print("Pos12 =",P_corr_rp12)
print("Neg12 =",P_corr_rn12)
print("Pos14 =",P_corr_rp14)
print("Neg14 =",P_corr_rn14)
print("Pos16 =",P_corr_rp16)
print("Neg16 =",P_corr_rn16)
print("Pos18 =",P_corr_rp18)
print("Neg18 =",P_corr_rn18)
print("Pos20 =",P_corr_rp20)
print("Neg20 =",P_corr_rn20)
print("Pos22 =",P_corr_rp22)
print("Neg22 =",P_corr_rn22)
print("Pos24 =",P_corr_rp24)
print("Neg24 =",P_corr_rn24)
print("Pos26 =",P_corr_rp26)
print("Neg26 =",P_corr_rn26)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

sub_cube1 = cube[12:14, 50:80, 50:65]
sub_cube1_rp2 = cube[12:14, 50:80, 50:65]
sub_cube1_rp4 = cube[12:14, 50:80, 50:65]
sub_cube1_rp6 = cube[12:14, 50:80, 50:65]
sub_cube1_rp8 = cube[12:14, 50:80, 50:65]
sub_cube1_rp10 = cube[12:14, 50:80, 50:65]
sub_cube1_rp12 = cube[12:14, 50:80, 50:65]
sub_cube1_rp14 = cube[12:14, 50:80, 50:65]
sub_cube1_rp16 = cube[12:14, 50:80, 50:65]
sub_cube1_rp18 = cube[12:14, 50:80, 50:65]
sub_cube1_rp20 = cube[12:14, 50:80, 50:65]
sub_cube1_rp22 = cube[12:14, 50:80, 50:65]
sub_cube1_rp24 = cube[12:14, 50:80, 50:65]
sub_cube1_rp26 = cube[12:14, 50:80, 50:65]
sub_cube1_rn2 = cube[12:14, 50:80, 50:65]
sub_cube1_rn4 = cube[12:14, 50:80, 50:65]
sub_cube1_rn6 = cube[12:14, 50:80, 50:65]
sub_cube1_rn8 = cube[12:14, 50:80, 50:65]
sub_cube1_rn10 = cube[12:14, 50:80, 50:65]
sub_cube1_rn12 = cube[12:14, 50:80, 50:65]
sub_cube1_rn14 = cube[12:14, 50:80, 50:65]
sub_cube1_rn16 = cube[12:14, 50:80, 50:65]
sub_cube1_rn18 = cube[12:14, 50:80, 50:65]
sub_cube1_rn20 = cube[12:14, 50:80, 50:65]
sub_cube1_rn22 = cube[12:14, 50:80, 50:65]
sub_cube1_rn24 = cube[12:14, 50:80, 50:65]
sub_cube1_rn26 = cube[12:14, 50:80, 50:65]

sub_cube2 = cube[14:16, 80:110, 50:65]
sub_cube2_rp2 = cube[14:16, 80:110, 50:65]
sub_cube2_rp4 = cube[14:16, 80:110, 51:66]
sub_cube2_rp6 = cube[14:16, 80:110, 52:67]
sub_cube2_rp8 = cube[14:16, 80:110, 52:67]
sub_cube2_rp10 = cube[14:16, 80:110, 53:68]
sub_cube2_rp12 = cube[14:16, 80:110, 53:68]
sub_cube2_rp14 = cube[14:16, 80:110, 54:69]
sub_cube2_rp16 = cube[14:16, 80:110, 54:69]
sub_cube2_rp18 = cube[14:16, 80:110, 55:70]
sub_cube2_rp20 = cube[14:16, 80:110, 56:71]
sub_cube2_rp22 = cube[14:16, 80:110, 56:71]
sub_cube2_rp24 = cube[14:16, 80:110, 57:72]
sub_cube2_rp26 = cube[14:16, 80:110, 57:72]
sub_cube2_rn2 = cube[14:16, 80:110, 50:65]
sub_cube2_rn4 = cube[14:16, 80:110, 49:64]
sub_cube2_rn6 = cube[14:16, 80:110, 48:63]
sub_cube2_rn8 = cube[14:16, 80:110, 48:63]
sub_cube2_rn10 = cube[14:16, 80:110, 47:62]
sub_cube2_rn12 = cube[14:16, 80:110, 47:62]
sub_cube2_rn14 = cube[14:16, 80:110, 46:61]
sub_cube2_rn16 = cube[14:16, 80:110, 46:61]
sub_cube2_rn18 = cube[14:16, 80:110, 45:60]
sub_cube2_rn20 = cube[14:16, 80:110, 44:59]
sub_cube2_rn22 = cube[14:16, 80:110, 44:59]
sub_cube2_rn24 = cube[14:16, 80:110, 43:58]
sub_cube2_rn26 = cube[14:16, 80:110, 43:58]

sub_cube3 = cube[16:18, 110:140, 50:65]
sub_cube3_rp2 = cube[16:18, 110:140, 51:66]
sub_cube3_rp4 = cube[16:18, 110:140, 52:67]
sub_cube3_rp6 = cube[16:18, 110:140, 53:68]
sub_cube3_rp8 = cube[16:18, 110:140, 54:69]
sub_cube3_rp10 = cube[16:18, 110:140, 55:70]
sub_cube3_rp12 = cube[16:18, 110:140, 56:71]
sub_cube3_rp14 = cube[16:18, 110:140, 58:73]
sub_cube3_rp16 = cube[16:18, 110:140, 59:74]
sub_cube3_rp18 = cube[16:18, 110:140, 60:75]
sub_cube3_rp20 = cube[16:18, 110:140, 61:76]
sub_cube3_rp22 = cube[16:18, 110:140, 62:77]
sub_cube3_rp24 = cube[16:18, 110:140, 64:79]
sub_cube3_rp26 = cube[16:18, 110:140, 65:80]
sub_cube3_rn2 = cube[16:18, 110:140, 49:64]
sub_cube3_rn4 = cube[16:18, 110:140, 48:63]
sub_cube3_rn6 = cube[16:18, 110:140, 47:62]
sub_cube3_rn8 = cube[16:18, 110:140, 46:61]
sub_cube3_rn10 = cube[16:18, 110:140, 45:60]
sub_cube3_rn12 = cube[16:18, 110:140, 44:59]
sub_cube3_rn14 = cube[16:18, 110:140, 42:57]
sub_cube3_rn16 = cube[16:18, 110:140, 41:56]
sub_cube3_rn18 = cube[16:18, 110:140, 40:55]
sub_cube3_rn20 = cube[16:18, 110:140, 39:54]
sub_cube3_rn22 = cube[16:18, 110:140, 38:53]
sub_cube3_rn24 = cube[16:18, 110:140, 36:51]
sub_cube3_rn26 = cube[16:18, 110:140, 35:50]

sub_cube4 = cube[18:20, 140:170, 50:65]
sub_cube4_rp2 = cube[18:20, 140:170, 52:67]
sub_cube4_rp4 = cube[18:20, 140:170, 53:68]
sub_cube4_rp6 = cube[18:20, 140:170, 55:70]
sub_cube4_rp8 = cube[18:20, 140:170, 56:71]
sub_cube4_rp10 = cube[18:20, 140:170, 58:73]
sub_cube4_rp12 = cube[18:20, 140:170, 60:75]
sub_cube4_rp14 = cube[18:20, 140:170, 61:76]
sub_cube4_rp16 = cube[18:20, 140:170, 63:78]
sub_cube4_rp18 = cube[18:20, 140:170, 65:80]
sub_cube4_rp20 = cube[18:20, 140:170, 67:82]
sub_cube4_rp22 = cube[18:20, 140:170, 69:84]
sub_cube4_rp24 = cube[18:20, 140:170, 70:85]
sub_cube4_rp26 = cube[18:20, 140:170, 72:87]
sub_cube4_rn2 = cube[18:20, 140:170, 48:63]
sub_cube4_rn4 = cube[18:20, 140:170, 47:62]
sub_cube4_rn6 = cube[18:20, 140:170, 45:60]
sub_cube4_rn8 = cube[18:20, 140:170, 44:59]
sub_cube4_rn10 = cube[18:20, 140:170, 42:57]
sub_cube4_rn12 = cube[18:20, 140:170, 40:55]
sub_cube4_rn14 = cube[18:20, 140:170, 39:54]
sub_cube4_rn16 = cube[18:20, 140:170, 37:52]
sub_cube4_rn18 = cube[18:20, 140:170, 35:50]
sub_cube4_rn20 = cube[18:20, 140:170, 33:48]
sub_cube4_rn22 = cube[18:20, 140:170, 31:46]
sub_cube4_rn24 = cube[18:20, 140:170, 30:45]
sub_cube4_rn26 = cube[18:20, 140:170, 28:43]


for i in range(0, 15):
  for j in range(0, 30):
    for r in range (0, 2):
      x = i
      y = j
      z = r
a1 = np.average(sub_cube1)
a1_rp2 = np.average(sub_cube1_rp2)
a1_rp4 = np.average(sub_cube1_rp4)
a1_rp6 = np.average(sub_cube1_rp6)
a1_rp8 = np.average(sub_cube1_rp8)
a1_rp10 = np.average(sub_cube1_rp10)
a1_rp12 = np.average(sub_cube1_rp12)
a1_rp14 = np.average(sub_cube1_rp14)
a1_rp16 = np.average(sub_cube1_rp16)
a1_rp18 = np.average(sub_cube1_rp18)
a1_rp20 = np.average(sub_cube1_rp20)
a1_rp22 = np.average(sub_cube1_rp22)
a1_rp24 = np.average(sub_cube1_rp24)
a1_rp26 = np.average(sub_cube1_rp26)
a1_rn2 = np.average(sub_cube1_rn2)
a1_rn4 = np.average(sub_cube1_rn4)
a1_rn6 = np.average(sub_cube1_rn6)
a1_rn8 = np.average(sub_cube1_rn8)
a1_rn10 = np.average(sub_cube1_rn10)
a1_rn12 = np.average(sub_cube1_rn12)
a1_rn14 = np.average(sub_cube1_rn14)
a1_rn16 = np.average(sub_cube1_rn16)
a1_rn18 = np.average(sub_cube1_rn18)
a1_rn20 = np.average(sub_cube1_rn20)
a1_rn22 = np.average(sub_cube1_rn22)
a1_rn24 = np.average(sub_cube1_rn24)
a1_rn26 = np.average(sub_cube1_rn26)

a2 = np.average(sub_cube2)
a2_rp2 = np.average(sub_cube2_rp2)
a2_rp4 = np.average(sub_cube2_rp4)
a2_rp6 = np.average(sub_cube2_rp6)
a2_rp8 = np.average(sub_cube2_rp8)
a2_rp10 = np.average(sub_cube2_rp10)
a2_rp12 = np.average(sub_cube2_rp12)
a2_rp14 = np.average(sub_cube2_rp14)
a2_rp16 = np.average(sub_cube2_rp16)
a2_rp18 = np.average(sub_cube2_rp18)
a2_rp20 = np.average(sub_cube2_rp20)
a2_rp22 = np.average(sub_cube2_rp22)
a2_rp24 = np.average(sub_cube2_rp24)
a2_rp26 = np.average(sub_cube2_rp26)
a2_rn2 = np.average(sub_cube2_rn2)
a2_rn4 = np.average(sub_cube2_rn4)
a2_rn6 = np.average(sub_cube2_rn6)
a2_rn8 = np.average(sub_cube2_rn8)
a2_rn10 = np.average(sub_cube2_rn10)
a2_rn12 = np.average(sub_cube2_rn12)
a2_rn14 = np.average(sub_cube2_rn14)
a2_rn16 = np.average(sub_cube2_rn16)
a2_rn18 = np.average(sub_cube2_rn18)
a2_rn20 = np.average(sub_cube2_rn20)
a2_rn22 = np.average(sub_cube2_rn22)
a2_rn24 = np.average(sub_cube2_rn24)
a2_rn26 = np.average(sub_cube2_rn26)

a3 = np.average(sub_cube3)
a3_rp2 = np.average(sub_cube3_rp2)
a3_rp4 = np.average(sub_cube3_rp4)
a3_rp6 = np.average(sub_cube3_rp6)
a3_rp8 = np.average(sub_cube3_rp8)
a3_rp10 = np.average(sub_cube3_rp10)
a3_rp12 = np.average(sub_cube3_rp12)
a3_rp14 = np.average(sub_cube3_rp14)
a3_rp16 = np.average(sub_cube3_rp16)
a3_rp18 = np.average(sub_cube3_rp18)
a3_rp20 = np.average(sub_cube3_rp20)
a3_rp22 = np.average(sub_cube3_rp22)
a3_rp24 = np.average(sub_cube3_rp24)
a3_rp26 = np.average(sub_cube3_rp26)
a3_rn2 = np.average(sub_cube3_rn2)
a3_rn4 = np.average(sub_cube3_rn4)
a3_rn6 = np.average(sub_cube3_rn6)
a3_rn8 = np.average(sub_cube3_rn8)
a3_rn10 = np.average(sub_cube3_rn10)
a3_rn12 = np.average(sub_cube3_rn12)
a3_rn14 = np.average(sub_cube3_rn14)
a3_rn16 = np.average(sub_cube3_rn16)
a3_rn18 = np.average(sub_cube3_rn18)
a3_rn20 = np.average(sub_cube3_rn20)
a3_rn22 = np.average(sub_cube3_rn22)
a3_rn24 = np.average(sub_cube3_rn24)
a3_rn26 = np.average(sub_cube3_rn26)

a4 = np.average(sub_cube4)
a4_rp2 = np.average(sub_cube4_rp2)
a4_rp4 = np.average(sub_cube4_rp4)
a4_rp6 = np.average(sub_cube4_rp6)
a4_rp8 = np.average(sub_cube4_rp8)
a4_rp10 = np.average(sub_cube4_rp10)
a4_rp12 = np.average(sub_cube4_rp12)
a4_rp14 = np.average(sub_cube4_rp14)
a4_rp16 = np.average(sub_cube4_rp16)
a4_rp18 = np.average(sub_cube4_rp18)
a4_rp20 = np.average(sub_cube4_rp20)
a4_rp22 = np.average(sub_cube4_rp22)
a4_rp24 = np.average(sub_cube4_rp24)
a4_rp26 = np.average(sub_cube4_rp26)
a4_rn2 = np.average(sub_cube4_rn2)
a4_rn4 = np.average(sub_cube4_rn4)
a4_rn6 = np.average(sub_cube4_rn6)
a4_rn8 = np.average(sub_cube4_rn8)
a4_rn10 = np.average(sub_cube4_rn10)
a4_rn12 = np.average(sub_cube4_rn12)
a4_rn14 = np.average(sub_cube4_rn14)
a4_rn16 = np.average(sub_cube4_rn16)
a4_rn18 = np.average(sub_cube4_rn18)
a4_rn20 = np.average(sub_cube4_rn20)
a4_rn22 = np.average(sub_cube4_rn22)
a4_rn24 = np.average(sub_cube4_rn24)
a4_rn26 = np.average(sub_cube4_rn26)



sum = a1 + a2 + a3 + a4
sum_rp2 = a1_rp2 + a2_rp2 + a3_rp2 + a4_rp2
sum_rp4 = a1_rp4 + a2_rp4 + a3_rp4 + a4_rp4
sum_rp6 = a1_rp6 + a2_rp6 + a3_rp6 + a4_rp6
sum_rp8 = a1_rp8 + a2_rp8 + a3_rp8 + a4_rp8
sum_rp10 = a1_rp10 + a2_rp10 + a3_rp10 + a4_rp10
sum_rp12 = a1_rp12 + a2_rp12 + a3_rp12 + a4_rp12
sum_rp14 = a1_rp14 + a2_rp14 + a3_rp14 + a4_rp14
sum_rp16 = a1_rp16 + a2_rp16 + a3_rp16 + a4_rp16
sum_rp18 = a1_rp18 + a2_rp18 + a3_rp18 + a4_rp18
sum_rp20 = a1_rp20 + a2_rp20 + a3_rp20 + a4_rp20
sum_rp22 = a1_rp22 + a2_rp22 + a3_rp22 + a4_rp22
sum_rp24 = a1_rp24 + a2_rp24 + a3_rp24 + a4_rp24
sum_rp26 = a1_rp26 + a2_rp26 + a3_rp26 + a4_rp26
sum_rn2 = a1_rn2 + a2_rn2 + a3_rn2 + a4_rn2
sum_rn4 = a1_rn4 + a2_rn4 + a3_rn4 + a4_rn4
sum_rn6 = a1_rn6 + a2_rn6 + a3_rn6 + a4_rn6
sum_rn8 = a1_rn8 + a2_rn8 + a3_rn8 + a4_rn8
sum_rn10 = a1_rn10 + a2_rn10 + a3_rn10 + a4_rn10
sum_rn12 = a1_rn12 + a2_rn12 + a3_rn12 + a4_rn12
sum_rn14 = a1_rn14 + a2_rn14 + a3_rn14 + a4_rn14
sum_rn16 = a1_rn16 + a2_rn16 + a3_rn16 + a4_rn16
sum_rn18 = a1_rn18 + a2_rn18 + a3_rn18 + a4_rn18
sum_rn20 = a1_rn20 + a2_rn20 + a3_rn20 + a4_rn20
sum_rn22 = a1_rn22 + a2_rn22 + a3_rn22 + a4_rn22
sum_rn24 = a1_rn24 + a2_rn24 + a3_rn24 + a4_rn24
sum_rn26 = a1_rn26 + a2_rn26 + a3_rn26 + a4_rn26

print("Sum = ", sum)
print("Sum_rp2 = ", sum_rp2)
print("Sum_rn2 = ", sum_rn2)
print("Sum_rp4 = ", sum_rp4)
print("Sum_rn4 = ", sum_rn4)
print("Sum_rp6 = ", sum_rp6)
print("Sum_rn6 = ", sum_rn6)
print("Sum_rp8 = ", sum_rp8)
print("Sum_rn8 = ", sum_rn8)
print("Sum_rp10 = ", sum_rp10)
print("Sum_rn10 = ", sum_rn10)
print("Sum_rp12 = ", sum_rp12)
print("Sum_rn12 = ", sum_rn12)
print("Sum_rp14 = ", sum_rp14)
print("Sum_rn14 = ", sum_rn14)
print("Sum_rp16 = ", sum_rp16)
print("Sum_rn16 = ", sum_rn16)
print("Sum_rp18 = ", sum_rp18)
print("Sum_rn18 = ", sum_rn18)
print("Sum_rp20 = ", sum_rp20)
print("Sum_rn20 = ", sum_rn20)
print("Sum_rp22 = ", sum_rp22)
print("Sum_rn22 = ", sum_rn22)
print("Sum_rp24 = ", sum_rp24)
print("Sum_rn24 = ", sum_rn24)
print("Sum_rp26 = ", sum_rp26)
print("Sum_rn26 = ", sum_rn26)

diff_sigma = (sum * 5.7) / 0.00046608012
diff_sigma_rp2 = (sum_rp2 * 5.7) / 0.00046608012
diff_sigma_rn2 = (sum_rn2 * 5.7) / 0.00046608012
diff_sigma_rp4 = (sum_rp4 * 5.7) / 0.00046608012
diff_sigma_rn4 = (sum_rn4 * 5.7) / 0.00046608012
diff_sigma_rp6 = (sum_rp6 * 5.7) / 0.00046608012
diff_sigma_rn6 = (sum_rn6 * 5.7) / 0.00046608012
diff_sigma_rp8 = (sum_rp8 * 5.7) / 0.00046608012
diff_sigma_rn8 = (sum_rn8 * 5.7) / 0.00046608012
diff_sigma_rp10 = (sum_rp10 * 5.7) / 0.00046608012
diff_sigma_rn10 = (sum_rn10 * 5.7) / 0.00046608012
diff_sigma_rp12 = (sum_rp12 * 5.7) / 0.00046608012
diff_sigma_rn12 = (sum_rn12 * 5.7) / 0.00046608012
diff_sigma_rp14 = (sum_rp14 * 5.7) / 0.00046608012
diff_sigma_rn14 = (sum_rn14 * 5.7) / 0.00046608012
diff_sigma_rp16 = (sum_rp16 * 5.7) / 0.00046608012
diff_sigma_rn16 = (sum_rn16 * 5.7) / 0.00046608012
diff_sigma_rp18 = (sum_rp18 * 5.7) / 0.00046608012
diff_sigma_rn18 = (sum_rn18 * 5.7) / 0.00046608012
diff_sigma_rp20 = (sum_rp20 * 5.7) / 0.00046608012
diff_sigma_rn20 = (sum_rn20 * 5.7) / 0.00046608012
diff_sigma_rp22 = (sum_rp22 * 5.7) / 0.00046608012
diff_sigma_rn22 = (sum_rn22 * 5.7) / 0.00046608012
diff_sigma_rp24 = (sum_rp24 * 5.7) / 0.00046608012
diff_sigma_rn24 = (sum_rn24 * 5.7) / 0.00046608012
diff_sigma_rp26 = (sum_rp26 * 5.7) / 0.00046608012
diff_sigma_rn26 = (sum_rn26 * 5.7) / 0.00046608012

print("Sigma p0 = ", diff_sigma)
print("Sigma rp2 = ", diff_sigma_rp2)
print("Sigma rn2 = ", diff_sigma_rn2)
print("Sigma rp4 = ", diff_sigma_rp4)
print("Sigma rn4 = ", diff_sigma_rn4)
print("Sigma rp6 = ", diff_sigma_rp6)
print("Sigma rn6 = ", diff_sigma_rn6)
print("Sigma rp8 = ", diff_sigma_rp8)
print("Sigma rn8 = ", diff_sigma_rn8)
print("Sigma rp10 = ", diff_sigma_rp10)
print("Sigma rn10 = ", diff_sigma_rn10)
print("Sigma rp12 = ", diff_sigma_rp12)
print("Sigma rn12 = ", diff_sigma_rn12)
print("Sigma rp14 = ", diff_sigma_rp14)
print("Sigma rn14 = ", diff_sigma_rn14)
print("Sigma rp16 = ", diff_sigma_rp16)
print("Sigma rn16 = ", diff_sigma_rn16)
print("Sigma rp18 = ", diff_sigma_rp18)
print("Sigma rn18 = ", diff_sigma_rn18)
print("Sigma rp20 = ", diff_sigma_rp20)
print("Sigma rn20 = ", diff_sigma_rn20)
print("Sigma rp22 = ", diff_sigma_rp22)
print("Sigma rn22 = ", diff_sigma_rn22)
print("Sigma rp24 = ", diff_sigma_rp24)
print("Sigma rn24 = ", diff_sigma_rn24)
print("Sigma rp26 = ", diff_sigma_rp26)
print("Sigma rn26 = ", diff_sigma_rn26)

P_norm = scipy.stats.norm.sf(abs(5.7))

P_stat = scipy.stats.norm.sf(abs(diff_sigma))
P_stat_rp2 = scipy.stats.norm.sf(abs(diff_sigma_rp2))
P_stat_rn2 = scipy.stats.norm.sf(abs(diff_sigma_rn2))
P_stat_rp4 = scipy.stats.norm.sf(abs(diff_sigma_rp4))
P_stat_rn4 = scipy.stats.norm.sf(abs(diff_sigma_rn4))
P_stat_rp6 = scipy.stats.norm.sf(abs(diff_sigma_rp6))
P_stat_rn6 = scipy.stats.norm.sf(abs(diff_sigma_rn6))
P_stat_rp8 = scipy.stats.norm.sf(abs(diff_sigma_rp8))
P_stat_rn8 = scipy.stats.norm.sf(abs(diff_sigma_rn8))
P_stat_rp10 = scipy.stats.norm.sf(abs(diff_sigma_rp10))
P_stat_rn10 = scipy.stats.norm.sf(abs(diff_sigma_rn10))
P_stat_rp12 = scipy.stats.norm.sf(abs(diff_sigma_rp12))
P_stat_rn12 = scipy.stats.norm.sf(abs(diff_sigma_rn12))
P_stat_rp14 = scipy.stats.norm.sf(abs(diff_sigma_rp14))
P_stat_rn14 = scipy.stats.norm.sf(abs(diff_sigma_rn14))
P_stat_rp16 = scipy.stats.norm.sf(abs(diff_sigma_rp16))
P_stat_rn16 = scipy.stats.norm.sf(abs(diff_sigma_rn16))
P_stat_rp18 = scipy.stats.norm.sf(abs(diff_sigma_rp18))
P_stat_rn18 = scipy.stats.norm.sf(abs(diff_sigma_rn18))
P_stat_rp20 = scipy.stats.norm.sf(abs(diff_sigma_rp20))
P_stat_rn20 = scipy.stats.norm.sf(abs(diff_sigma_rn20))
P_stat_rp22 = scipy.stats.norm.sf(abs(diff_sigma_rp22))
P_stat_rn22 = scipy.stats.norm.sf(abs(diff_sigma_rn22))
P_stat_rp24 = scipy.stats.norm.sf(abs(diff_sigma_rp24))
P_stat_rn24 = scipy.stats.norm.sf(abs(diff_sigma_rn24))
P_stat_rp26 = scipy.stats.norm.sf(abs(diff_sigma_rp26))
P_stat_rn26 = scipy.stats.norm.sf(abs(diff_sigma_rn26))


P_corr = P_stat / (5 * P_norm)
P_corr_rp2 = P_stat_rp2 / (7* P_norm)
P_corr_rn2 = P_stat_rn2 / (3 * P_norm)
P_corr_rp4 = P_stat_rp4 / (9 * P_norm)
P_corr_rn4 = P_stat_rn4 / (1 * P_norm)
P_corr_rp6 = P_stat_rp6 / (11 * P_norm)
P_corr_rn6 = P_stat_rn6 / (3 * P_norm)
P_corr_rp8 = P_stat_rp8 / (13 * P_norm)
P_corr_rn8 = P_stat_rn8 / (5 * P_norm)
P_corr_rp10 = P_stat_rp10 / (15 * P_norm)
P_corr_rn10 = P_stat_rn10 / (7 * P_norm)
P_corr_rp12 = P_stat_rp12 / (17 * P_norm)
P_corr_rn12 = P_stat_rn12 / (9 * P_norm)
P_corr_rp14 = P_stat_rp14 / (19 * P_norm)
P_corr_rn14 = P_stat_rn14 / (11 * P_norm)
P_corr_rp16 = P_stat_rp16 / (21 * P_norm)
P_corr_rn16 = P_stat_rn16 / (13 * P_norm)
P_corr_rp18 = P_stat_rp18 / (23 * P_norm)
P_corr_rn18 = P_stat_rn18 / (15 * P_norm)
P_corr_rp20 = P_stat_rp20 / (25 * P_norm)
P_corr_rn20 = P_stat_rn20 / (17 * P_norm)
P_corr_rp22 = P_stat_rp22 / (27 * P_norm)
P_corr_rn22 = P_stat_rn22 / (19 * P_norm)
P_corr_rp24 = P_stat_rp24 / (29 * P_norm)
P_corr_rn24 = P_stat_rn24 / (21 * P_norm)
P_corr_rp26 = P_stat_rp26 / (31 * P_norm)
P_corr_rn26 = P_stat_rn26 / (23 * P_norm)



print(P_corr)
print("Pos2 =",P_corr_rp2)
print("Neg2 =",P_corr_rn2)
print("Pos4 =",P_corr_rp4)
print("Neg4 =",P_corr_rn4)
print("Pos6 =",P_corr_rp6)
print("Neg6 =",P_corr_rn6)
print("Pos8 =",P_corr_rp8)
print("Neg8 =",P_corr_rn8)
print("Pos10 =",P_corr_rp10)
print("Neg10 =",P_corr_rn10)
print("Pos12 =",P_corr_rp12)
print("Neg12 =",P_corr_rn12)
print("Pos14 =",P_corr_rp14)
print("Neg14 =",P_corr_rn14)
print("Pos16 =",P_corr_rp16)
print("Neg16 =",P_corr_rn16)
print("Pos18 =",P_corr_rp18)
print("Neg18 =",P_corr_rn18)
print("Pos20 =",P_corr_rp20)
print("Neg20 =",P_corr_rn20)
print("Pos22 =",P_corr_rp22)
print("Neg22 =",P_corr_rn22)
print("Pos24 =",P_corr_rp24)
print("Neg24 =",P_corr_rn24)
print("Pos26 =",P_corr_rp26)
print("Neg26 =",P_corr_rn26)
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_2
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING:astropy:WCSWarning: WCS1 is missing card PV2_1
# ...
